# %%
import os

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
os.chdir('../..')

# %%
BATCH_SIZE = 32

# %% [markdown]
# ### Question type

# %%
question_type_squad1 = pd.DataFrame()

seeds = [28, 29, 30]
filepaths=[
    'data/processed/metrics_by_w6h-albert-xlarge-v2-squadv1-wu=100-lr=3e5-bs=32-msl=384-seed=28.csv',
    'data/processed/metrics_by_w6h-albert-xlarge-v2-squadv1-wu=100-lr=3e5-bs=32-msl=384-seed=29.csv',
    'data/processed/metrics_by_w6h-albert-xlarge-v2-squadv1-wu=100-lr=3e5-bs=32-msl=384-seed=30.csv'
]

for seed, fp in zip(seeds, filepaths):
    df = pd.read_csv(fp)
    df['seed'] = seed
    question_type_squad1 = question_type_squad1.append(df)
    
question_type_squad1['num_examples'] = question_type_squad1['checkpoint'] * BATCH_SIZE

# %%
question_type_squad2 = pd.DataFrame()

seeds = [27, 29, 30]
filepaths=[
    'data/processed/metrics_by_w6h-albert-xlarge-v2-squadv2-wu=100-lr=3e5-bs=32-msl=384-seed=27.csv',
    'data/processed/metrics_by_w6h-albert-xlarge-v2-squadv2-wu=100-lr=3e5-bs=32-msl=384-seed=29.csv',
    'data/processed/metrics_by_w6h-albert-xlarge-v2-squadv2-wu=100-lr=3e5-bs=32-msl=384-seed=30.csv'
]

for seed, fp in zip(seeds, filepaths):
    df = pd.read_csv(fp)
    df['seed'] = seed
    question_type_squad2 = question_type_squad2.append(df)
    
question_type_squad2['num_examples'] = question_type_squad2['checkpoint'] * BATCH_SIZE

# %%
question_type_squad2_AnsOnly = pd.DataFrame()

seeds = [27, 29, 30]
filepaths=[
    'data/processed/metrics_by_w6h-albert-xlarge-v2-squadv2-wu=100-lr=3e5-bs=32-msl=384-seed=27-AnsOnly.csv',
    'data/processed/metrics_by_w6h-albert-xlarge-v2-squadv2-wu=100-lr=3e5-bs=32-msl=384-seed=29-AnsOnly.csv',
    'data/processed/metrics_by_w6h-albert-xlarge-v2-squadv2-wu=100-lr=3e5-bs=32-msl=384-seed=30-AnsOnly.csv'
]

for seed, fp in zip(seeds, filepaths):
    df = pd.read_csv(fp)
    df['seed'] = seed
    question_type_squad2_AnsOnly = question_type_squad2_AnsOnly.append(df)
    
question_type_squad2_AnsOnly['num_examples'] = question_type_squad2_AnsOnly['checkpoint'] * BATCH_SIZE

# %% [markdown]
# ### Question length

# %%
question_length_squad1 = pd.DataFrame()

seeds = [28, 29, 30]
filepaths=[
    'data/processed/metrics_by_question_length_bin-albert-xlarge-v2-squadv1-wu=100-lr=3e5-bs=32-msl=384-seed=28.csv',
    'data/processed/metrics_by_question_length_bin-albert-xlarge-v2-squadv1-wu=100-lr=3e5-bs=32-msl=384-seed=29.csv',
    'data/processed/metrics_by_question_length_bin-albert-xlarge-v2-squadv1-wu=100-lr=3e5-bs=32-msl=384-seed=30.csv'
]

for seed, fp in zip(seeds, filepaths):
    df = pd.read_csv(fp)
    df['seed'] = seed
    question_length_squad1 = question_length_squad1.append(df)
    
question_length_squad1['num_examples'] = question_length_squad1['checkpoint'] * BATCH_SIZE

# %%
question_length_squad2 = pd.DataFrame()

seeds = [27, 29, 30]
filepaths=[
    'data/processed/metrics_by_question_length_bin-albert-xlarge-v2-squadv2-wu=100-lr=3e5-bs=32-msl=384-seed=27.csv',
    'data/processed/metrics_by_question_length_bin-albert-xlarge-v2-squadv2-wu=100-lr=3e5-bs=32-msl=384-seed=29.csv',
    'data/processed/metrics_by_question_length_bin-albert-xlarge-v2-squadv2-wu=100-lr=3e5-bs=32-msl=384-seed=30.csv'
]

for seed, fp in zip(seeds, filepaths):
    df = pd.read_csv(fp)
    df['seed'] = seed
    question_length_squad2 = question_length_squad2.append(df)
    
question_length_squad2['num_examples'] = question_length_squad2['checkpoint'] * BATCH_SIZE

# %%
question_length_squad2_AnsOnly = pd.DataFrame()

seeds = [27, 29, 30]
filepaths=[
    'data/processed/metrics_by_question_length_bin-albert-xlarge-v2-squadv2-wu=100-lr=3e5-bs=32-msl=384-seed=27-AnsOnly.csv',
    'data/processed/metrics_by_question_length_bin-albert-xlarge-v2-squadv2-wu=100-lr=3e5-bs=32-msl=384-seed=29-AnsOnly.csv',
    'data/processed/metrics_by_question_length_bin-albert-xlarge-v2-squadv2-wu=100-lr=3e5-bs=32-msl=384-seed=30-AnsOnly.csv'
]

for seed, fp in zip(seeds, filepaths):
    df = pd.read_csv(fp)
    df['seed'] = seed
    question_length_squad2_AnsOnly = question_length_squad2_AnsOnly.append(df)
    
question_length_squad2_AnsOnly['num_examples'] = question_length_squad2_AnsOnly['checkpoint'] * BATCH_SIZE

# %% [markdown]
# ### Answer type

# %%
answer_type_squad1 = pd.DataFrame()

seeds = [28, 29, 30]
filepaths=[
    'data/processed/metrics_by_answer_type-albert-xlarge-v2-squadv1-wu=100-lr=3e5-bs=32-msl=384-seed=28.csv',
    'data/processed/metrics_by_answer_type-albert-xlarge-v2-squadv1-wu=100-lr=3e5-bs=32-msl=384-seed=29.csv',
    'data/processed/metrics_by_answer_type-albert-xlarge-v2-squadv1-wu=100-lr=3e5-bs=32-msl=384-seed=30.csv'
]

for seed, fp in zip(seeds, filepaths):
    df = pd.read_csv(fp)
    df['seed'] = seed
    answer_type_squad1 = answer_type_squad1.append(df)
    
answer_type_squad1['num_examples'] = answer_type_squad1['checkpoint'] * BATCH_SIZE

# %%
answer_type_squad2 = pd.DataFrame()

seeds = [27, 29, 30]
filepaths=[
    'data/processed/metrics_by_answer_type-albert-xlarge-v2-squadv2-wu=100-lr=3e5-bs=32-msl=384-seed=27.csv',
    'data/processed/metrics_by_answer_type-albert-xlarge-v2-squadv2-wu=100-lr=3e5-bs=32-msl=384-seed=29.csv',
    'data/processed/metrics_by_answer_type-albert-xlarge-v2-squadv2-wu=100-lr=3e5-bs=32-msl=384-seed=30.csv'
]

for seed, fp in zip(seeds, filepaths):
    df = pd.read_csv(fp)
    df['seed'] = seed
    answer_type_squad2 = answer_type_squad2.append(df)
    
answer_type_squad2['num_examples'] = answer_type_squad2['checkpoint'] * BATCH_SIZE

# %%
answer_type_squad2_AnsOnly = pd.DataFrame()

seeds = [27, 29, 30]
filepaths=[
    'data/processed/metrics_by_answer_type-albert-xlarge-v2-squadv2-wu=100-lr=3e5-bs=32-msl=384-seed=27-AnsOnly.csv',
    'data/processed/metrics_by_answer_type-albert-xlarge-v2-squadv2-wu=100-lr=3e5-bs=32-msl=384-seed=29-AnsOnly.csv',
    'data/processed/metrics_by_answer_type-albert-xlarge-v2-squadv2-wu=100-lr=3e5-bs=32-msl=384-seed=30-AnsOnly.csv'
]

for seed, fp in zip(seeds, filepaths):
    df = pd.read_csv(fp)
    df['seed'] = seed
    answer_type_squad2_AnsOnly = answer_type_squad2_AnsOnly.append(df)
    
answer_type_squad2_AnsOnly['num_examples'] = answer_type_squad2_AnsOnly['checkpoint'] * BATCH_SIZE

# %% [markdown]
# ### Answer length

# %%
answer_length_squad1 = pd.DataFrame()

seeds = [28, 29, 30]
filepaths=[
    'data/processed/metrics_by_answer_length_bin-albert-xlarge-v2-squadv1-wu=100-lr=3e5-bs=32-msl=384-seed=28.csv',
    'data/processed/metrics_by_answer_length_bin-albert-xlarge-v2-squadv1-wu=100-lr=3e5-bs=32-msl=384-seed=29.csv',
    'data/processed/metrics_by_answer_length_bin-albert-xlarge-v2-squadv1-wu=100-lr=3e5-bs=32-msl=384-seed=30.csv'
]

for seed, fp in zip(seeds, filepaths):
    df = pd.read_csv(fp)
    df['seed'] = seed
    answer_length_squad1 = answer_length_squad1.append(df)
    
answer_length_squad1['num_examples'] = answer_length_squad1['checkpoint'] * BATCH_SIZE

# %%
answer_length_squad2 = pd.DataFrame()

seeds = [27, 29, 30]
filepaths=[
    'data/processed/metrics_by_answer_length_bin-albert-xlarge-v2-squadv2-wu=100-lr=3e5-bs=32-msl=384-seed=27.csv',
    'data/processed/metrics_by_answer_length_bin-albert-xlarge-v2-squadv2-wu=100-lr=3e5-bs=32-msl=384-seed=29.csv',
    'data/processed/metrics_by_answer_length_bin-albert-xlarge-v2-squadv2-wu=100-lr=3e5-bs=32-msl=384-seed=30.csv'
]

for seed, fp in zip(seeds, filepaths):
    df = pd.read_csv(fp)
    df['seed'] = seed
    answer_length_squad2 = answer_length_squad2.append(df)
    
answer_length_squad2['num_examples'] = answer_length_squad2['checkpoint'] * BATCH_SIZE
answer_length_squad2 = answer_length_squad2[answer_length_squad2['answer_length_bin'] != '0']

# %%
answer_length_squad2_AnsOnly = pd.DataFrame()

seeds = [27, 29, 30]
filepaths=[
    'data/processed/metrics_by_answer_length_bin-albert-xlarge-v2-squadv2-wu=100-lr=3e5-bs=32-msl=384-seed=27-AnsOnly.csv',
    'data/processed/metrics_by_answer_length_bin-albert-xlarge-v2-squadv2-wu=100-lr=3e5-bs=32-msl=384-seed=29-AnsOnly.csv',
    'data/processed/metrics_by_answer_length_bin-albert-xlarge-v2-squadv2-wu=100-lr=3e5-bs=32-msl=384-seed=30-AnsOnly.csv'
]

for seed, fp in zip(seeds, filepaths):
    df = pd.read_csv(fp)
    df['seed'] = seed
    answer_length_squad2_AnsOnly = answer_length_squad2_AnsOnly.append(df)
    
answer_length_squad2_AnsOnly['num_examples'] = answer_length_squad2_AnsOnly['checkpoint'] * BATCH_SIZE
answer_length_squad2_AnsOnly = answer_length_squad2_AnsOnly[answer_length_squad2_AnsOnly['answer_length_bin'] != '0']

# %% [markdown]
# ### Context length

# %%
context_length_squad1 = pd.DataFrame()

seeds = [28, 29, 30]
filepaths=[
    'data/processed/metrics_by_context_length_bin-albert-xlarge-v2-squadv1-wu=100-lr=3e5-bs=32-msl=384-seed=28.csv',
    'data/processed/metrics_by_context_length_bin-albert-xlarge-v2-squadv1-wu=100-lr=3e5-bs=32-msl=384-seed=29.csv',
    'data/processed/metrics_by_context_length_bin-albert-xlarge-v2-squadv1-wu=100-lr=3e5-bs=32-msl=384-seed=30.csv'
]

for seed, fp in zip(seeds, filepaths):
    df = pd.read_csv(fp)
    df['seed'] = seed
    context_length_squad1 = context_length_squad1.append(df)
    
context_length_squad1['num_examples'] = context_length_squad1['checkpoint'] * BATCH_SIZE

# %%
context_length_squad2 = pd.DataFrame()

seeds = [27, 29, 30]
filepaths=[
    'data/processed/metrics_by_context_length_bin-albert-xlarge-v2-squadv2-wu=100-lr=3e5-bs=32-msl=384-seed=27.csv',
    'data/processed/metrics_by_context_length_bin-albert-xlarge-v2-squadv2-wu=100-lr=3e5-bs=32-msl=384-seed=29.csv',
    'data/processed/metrics_by_context_length_bin-albert-xlarge-v2-squadv2-wu=100-lr=3e5-bs=32-msl=384-seed=30.csv'
]

for seed, fp in zip(seeds, filepaths):
    df = pd.read_csv(fp)
    df['seed'] = seed
    context_length_squad2 = context_length_squad2.append(df)
    
context_length_squad2['num_examples'] = context_length_squad2['checkpoint'] * BATCH_SIZE

# %%
context_length_squad2_AnsOnly = pd.DataFrame()

seeds = [27, 29, 30]
filepaths=[
    'data/processed/metrics_by_context_length_bin-albert-xlarge-v2-squadv2-wu=100-lr=3e5-bs=32-msl=384-seed=27-AnsOnly.csv',
    'data/processed/metrics_by_context_length_bin-albert-xlarge-v2-squadv2-wu=100-lr=3e5-bs=32-msl=384-seed=29-AnsOnly.csv',
    'data/processed/metrics_by_context_length_bin-albert-xlarge-v2-squadv2-wu=100-lr=3e5-bs=32-msl=384-seed=30-AnsOnly.csv'
]

for seed, fp in zip(seeds, filepaths):
    df = pd.read_csv(fp)
    df['seed'] = seed
    context_length_squad2_AnsOnly = context_length_squad2_AnsOnly.append(df)
    
context_length_squad2_AnsOnly['num_examples'] = context_length_squad2_AnsOnly['checkpoint'] * BATCH_SIZE

# %% [markdown]
# ### Unanswerable

# %%
unanswerable_squad2 = pd.DataFrame()

seeds = [27, 29, 30]
filepaths=[
    'data/processed/metrics_by_unanswerable-albert-xlarge-v2-squadv2-wu=100-lr=3e5-bs=32-msl=384-seed=27.csv',
    'data/processed/metrics_by_unanswerable-albert-xlarge-v2-squadv2-wu=100-lr=3e5-bs=32-msl=384-seed=29.csv',
    'data/processed/metrics_by_unanswerable-albert-xlarge-v2-squadv2-wu=100-lr=3e5-bs=32-msl=384-seed=30.csv'
]

for seed, fp in zip(seeds, filepaths):
    df = pd.read_csv(fp)
    df['seed'] = seed
    unanswerable_squad2 = unanswerable_squad2.append(df)
    
unanswerable_squad2['num_examples'] = unanswerable_squad2['checkpoint'] * BATCH_SIZE

# %%
question_type_squad1 = question_type_squad1[question_type_squad1['num_examples'] < 15000]
question_length_squad1 = question_length_squad1[question_length_squad1['num_examples'] < 15000]
answer_length_squad1 = answer_length_squad1[answer_length_squad1['num_examples'] < 15000]
answer_type_squad1 = answer_type_squad1[answer_type_squad1['num_examples'] < 15000]
context_length_squad1 = context_length_squad1[context_length_squad1['num_examples'] < 15000]

question_type_squad2 = question_type_squad2[question_type_squad2['num_examples'] < 15000]
question_length_squad2 = question_length_squad2[question_length_squad2['num_examples'] < 15000]
answer_length_squad2 = answer_length_squad2[answer_length_squad2['num_examples'] < 15000]
answer_type_squad2 = answer_type_squad2[answer_type_squad2['num_examples'] < 15000]
context_length_squad2 = context_length_squad2[context_length_squad2['num_examples'] < 15000]
unanswerable_squad2 = unanswerable_squad2[
    (unanswerable_squad2['unanswerable'] == 1) & 
    (unanswerable_squad2['num_examples'] < 15000)
]

question_type_squad2_AnsOnly = question_type_squad2_AnsOnly[question_type_squad2_AnsOnly['num_examples'] < 15000]
question_length_squad2_AnsOnly = question_length_squad2_AnsOnly[question_length_squad2_AnsOnly['num_examples'] < 15000]
answer_length_squad2_AnsOnly = answer_length_squad2_AnsOnly[answer_length_squad2_AnsOnly['num_examples'] < 15000]
answer_type_squad2_AnsOnly = answer_type_squad2_AnsOnly[answer_type_squad2_AnsOnly['num_examples'] < 15000]
context_length_squad2_AnsOnly = context_length_squad2_AnsOnly[context_length_squad2_AnsOnly['num_examples'] < 15000]

# %% [markdown]
# ## Plot

# %%
# fig, axs = plt.subplots(nrows=5, ncols=3, sharex=True, sharey=True, figsize=(22.5, 25))
fig, axs = plt.subplots(nrows=5, ncols=3, sharex=True, sharey=True, figsize=(30, 30*297/210))

#=======================================#
# Question type
#=======================================#

# SQuAD 1
axs[0, 0].set_ylim(0, 100)
sns.lineplot(data=question_type_squad1, y='f1', x='num_examples', hue='w6h_label', marker='o', palette='tab10', ax=axs[0, 0], hue_order=['which', 'where', 'what', 'who', 'other', 'how', 'when', 'why'])
axs[0, 0].legend(loc='lower right', prop={'size': 14})

# SQuAD 2
axs[0, 1].set_ylim(0, 100)
sns.lineplot(data=question_type_squad2, y='f1', x='num_examples', hue='w6h_label', marker='o', palette='tab10', ax=axs[0, 1], hue_order=['which', 'where', 'what', 'who', 'other', 'how', 'when', 'why'])
axs[0, 1].legend(loc='lower right', prop={'size': 14})

# SQuAD 2 (Ans only)
axs[0, 2].set_ylim(0, 100)
sns.lineplot(data=question_type_squad2_AnsOnly, y='f1', x='num_examples', hue='w6h_label', marker='o', palette='tab10', ax=axs[0, 2], hue_order=['which', 'where', 'what', 'who', 'other', 'how', 'when', 'why'])
axs[0, 2].legend(loc='lower right', prop={'size': 14})

#=======================================#
# Question length
#=======================================#

# SQuAD 1
axs[1, 0].set_ylim(0, 100)
sns.lineplot(data=question_length_squad1, y='f1', x='num_examples', hue='question_length_bin', marker='o', palette='tab10', ax=axs[1, 0], hue_order=['0-5', '5-10', '10-15', '>15'])
axs[1, 0].legend(loc='lower right', prop={'size': 14})

# SQuAD 2
axs[1, 1].set_ylim(0, 100)
sns.lineplot(data=question_length_squad2, y='f1', x='num_examples', hue='question_length_bin', marker='o', palette='tab10', ax=axs[1, 1], hue_order=['0-5', '5-10', '10-15', '>15'])
axs[1, 1].legend(loc='lower right', prop={'size': 14})

# SQuAD 2 (Ans only)
axs[1, 2].set_ylim(0, 100)
sns.lineplot(data=question_length_squad2_AnsOnly, y='f1', x='num_examples', hue='question_length_bin', marker='o', palette='tab10', ax=axs[1, 2], hue_order=['0-5', '5-10', '10-15', '>15'])
axs[1, 2].legend(loc='lower right', prop={'size': 14})

#=======================================#
# Answer type
#=======================================#

# SQuAD 1
axs[2, 0].set_ylim(0, 100)
sns.lineplot(data=answer_type_squad1, y='f1', x='num_examples', hue='answer_type', marker='o', palette='tab10', ax=axs[2, 0], hue_order=['Organisation', 'Common Noun Phrase', 'Date', 'Other Entity', 'Location', 'Other Numeric', 'Person', 'Other', 'Adjective Phrase', 'Verb Phrase', 'Clause'])
axs[2, 0].legend(loc='lower right', prop={'size': 14})

# SQuAD 2
axs[2, 1].set_ylim(0, 100)
sns.lineplot(data=answer_type_squad2, y='f1', x='num_examples', hue='answer_type', marker='o', palette='tab10', ax=axs[2, 1], hue_order=['Organisation', 'Common Noun Phrase', 'Date', 'Other Entity', 'Location', 'Other Numeric', 'Person', 'Other', 'Adjective Phrase', 'Verb Phrase', 'Clause'])
sns.lineplot(data=unanswerable_squad2, y='f1', x='num_examples', color='darkviolet', ci=None, ax=axs[2, 1], linestyle='--', label='unanswerable')
axs[2, 1].legend(loc='lower right', prop={'size': 14})

# SQuAD 2 (Ans only)
axs[2, 2].set_ylim(0, 100)
sns.lineplot(data=answer_type_squad2_AnsOnly, y='f1', x='num_examples', hue='answer_type', marker='o', palette='tab10', ax=axs[2, 2], hue_order=['Organisation', 'Common Noun Phrase', 'Date', 'Other Entity', 'Location', 'Other Numeric', 'Person', 'Other', 'Adjective Phrase', 'Verb Phrase', 'Clause'])
sns.lineplot(data=unanswerable_squad2, y='f1', x='num_examples', color='darkviolet', ci=None, ax=axs[2, 2], linestyle='--', label='unanswerable')
axs[2, 2].legend(loc='lower right', prop={'size': 14})

#=======================================#
# Answer length
#=======================================#

# SQuAD 1
axs[3, 0].set_ylim(0, 100)
sns.lineplot(data=answer_length_squad1, y='f1', x='num_examples', hue='answer_length_bin', marker='o', palette='tab10', ax=axs[3, 0], hue_order=['1', '2', '3', '4', '5', '6', '7', '8', '9', '>9'])
axs[3, 0].legend(loc='lower right', prop={'size': 14})

# SQuAD 2
axs[3, 1].set_ylim(0, 100)
sns.lineplot(data=answer_length_squad2, y='f1', x='num_examples', hue='answer_length_bin', marker='o', palette='tab10', ax=axs[3, 1], hue_order=['1', '2', '3', '4', '5', '6', '7', '8', '9', '>9'])
sns.lineplot(data=unanswerable_squad2, y='f1', x='num_examples', color='darkviolet', ci=None, ax=axs[3, 1], linestyle='--', label='unanswerable')
axs[3, 1].legend(loc='lower right', prop={'size': 14})

# SQuAD 2 (Ans only)
axs[3, 2].set_ylim(0, 100)
sns.lineplot(data=answer_length_squad2_AnsOnly, y='f1', x='num_examples', hue='answer_length_bin', marker='o', palette='tab10', ax=axs[3, 2], hue_order=['1', '2', '3', '4', '5', '6', '7', '8', '9', '>9'])
sns.lineplot(data=unanswerable_squad2, y='f1', x='num_examples', color='darkviolet', ci=None, ax=axs[3, 2], linestyle='--', label='unanswerable')
axs[3, 2].legend(loc='lower right', prop={'size': 14})

#=======================================#
# Context length
#=======================================#

# SQuAD 1
axs[4, 0].set_ylim(0, 100)
axs[4, 0].set_xlabel('Number of training examples', fontsize=20)
sns.lineplot(data=context_length_squad1, y='f1', x='num_examples', hue='context_length_bin', marker='o', palette='tab10', ax=axs[4, 0], hue_order=['0-50', '50-100', '100-150', '150-200', '>200'])
axs[4, 0].legend(loc='lower right', prop={'size': 14})

# SQuAD 2
axs[4, 1].set_ylim(0, 100)
axs[4, 1].set_xlabel('Number of training examples', fontsize=20)
sns.lineplot(data=context_length_squad2, y='f1', x='num_examples', hue='context_length_bin', marker='o', palette='tab10', ax=axs[4, 1], hue_order=['0-50', '50-100', '100-150', '150-200', '>200'])
axs[4, 1].legend(loc='lower right', prop={'size': 14})

# SQuAD 2 (Ans only)
axs[4, 2].set_ylim(0, 100)
axs[4, 2].set_xlabel('Number of training examples', fontsize=20)
sns.lineplot(data=context_length_squad2_AnsOnly, y='f1', x='num_examples', hue='context_length_bin', marker='o', palette='tab10', ax=axs[4, 2], hue_order=['0-50', '50-100', '100-150', '150-200', '>200'])
axs[4, 2].legend(loc='lower right', prop={'size': 14})

#=======================================#

# Row and column labels:

cols = ['SQuAD 1.1\n', 'SQuAD 2.0\n', 'SQuAD 2.0 (Ans. only)\n']
rows = ['Question type\n\nF1', 'Question length\n\nF1', 'Answer type\n\nF1', 'Answer length\n\nF1', 'Context length\n\nF1']

for ax, col in zip(axs[0], cols):
    ax.set_title(col, fontsize=20)

for ax, row in zip(axs[:,0], rows):
    ax.set_ylabel(row, rotation=90, size='large', fontsize=20)

plt.tight_layout()

plt.savefig('reports/figures/squadv1-squadv2-comp-15k.pdf')

plt.show()
