# %%
import os
import re

import pandas as pd
import numpy as np
from datasets import load_dataset

# %%
os.chdir('../..')

# %%
pd.options.display.max_columns = None

# %% [markdown]
# ## Check label counts

# %%
df_labels = pd.DataFrame()

for dataset in ['SQuAD', 'DBERT', 'DBiDAF', 'DRoBERTa']:

    df = pd.read_csv(f'data/external/Reasoning Types/{dataset}.csv')
    df['id'] = df.index + 1
    df = pd.melt(df, id_vars=['id'], value_vars=['Reasoning Type', 'RT 2', 'RT 3'])
    df['dataset'] = dataset
    
    df_labels = df_labels.append(df)

# %%
df_labels.shape
# Out:
# (1200, 4)

# %%
df_labels.head()
# Out:
#    id        variable               value dataset
# 0   1  Reasoning Type            Explicit   SQuAD
# 1   2  Reasoning Type            Implicit   SQuAD
# 2   3  Reasoning Type  External Knowledge   SQuAD
# 3   4  Reasoning Type            Implicit   SQuAD
# 4   5  Reasoning Type            Implicit   SQuAD

# %%
df_labels['value'].isnull().sum()
# Out:
# 699

# %%
df_labels.dropna(axis=0, subset=['value'], inplace=True)

# %%
df_labels['value'].value_counts()
# Out:
# Paraphrasing          120
# Explicit               77
# Co-reference           61
# External Knowledge     59
# Implicit               52
# Multi-hop              41
# Filtering              23
# Temporal               20
# Spatial                11
# Comparative             8
# Inductive               8
# Superlative             7
# Numeric (other)         7
# Negation                7
# Name: value, dtype: int64

# %%
df_labels.groupby(['dataset', 'value']).nunique()['id']
# Out:
# dataset   value
# DBERT     Co-reference           9
#           Explicit               6
#           External Knowledge    19
#           Filtering              7
#           Implicit              18
#           Inductive              1
#           Multi-hop             12
#           Negation               3
#           Numeric (other)        5
#           Paraphrasing          35
#           Spatial                5
#           Superlative            1
#           Temporal               5
# DBiDAF    Co-reference          22
#           Comparative            6
#           Explicit               8
#           External Knowledge    12
#           Filtering              6
#           Implicit              11
#           Inductive              1
#           Multi-hop              9
#           Negation               2
#           Numeric (other)        2
#           Paraphrasing          41
#           Spatial                3
#           Superlative            5
#           Temporal               6
# DRoBERTa  Co-reference          13
#           Comparative            2
#           Explicit               6
#           External Knowledge    20
#           Filtering             10
#           Implicit              13
#           Inductive              6
#           Multi-hop             18
#           Negation               2
#           Paraphrasing          27
#           Spatial                3
#           Superlative            1
#           Temporal               8
# SQuAD     Co-reference          17
#           Explicit              57
#           External Knowledge     8
#           Implicit              10
#           Multi-hop              2
#           Paraphrasing          17
#           Temporal               1
# Name: id, dtype: int64

# %% [markdown]
# ## SQuAD

# %%
squad_reasoning = pd.read_csv('data/external/Reasoning Types/SQuAD.csv')
print(squad_reasoning.shape)
squad_reasoning.head()
# Out:
# (100, 7)
#                                              Passage  \
# 0  The Central Region, consisting of present-day ...
# 1  Manning finished the game 13 of 23 for 141 yar...
# 2  In business, notable alumni include Microsoft ...
# 3  Manning finished the game 13 of 23 for 141 yar...
# 4  The collection of Italian, Medieval, Renaissan...
#
#                                             Question                Answer  \
# 0           Where was the Central Secretariat based?             Khanbaliq
# 1  What is th elast name of the player who was th...              Anderson
# 2  What Goldman Sachs CEO is also an alumni of th...           Jon Corzine
# 3  How many intercpetions did Newton have in Supe...                   one
# 4  Who designed the largest item from Italy that ...  Giuliano da Sangallo
#
#        Reasoning Type RT 2  RT 3 Comments
# 0            Explicit  NaN   NaN      NaN
# 1            Implicit  NaN   NaN      NaN
# 2  External Knowledge  NaN   NaN      NaN
# 3            Implicit  NaN   NaN      NaN
# 4            Implicit  NaN   NaN      NaN

# %%
squad_reasoning['Passage_letters_only'] = squad_reasoning['Passage'].apply(lambda x: re.sub(r"[^a-zA-Z]+", '', x))

# %%
squad = load_dataset("squad", split="validation")
squad_df = pd.DataFrame(squad)
print(squad_df.shape)
squad_df.head()
# Out:
# Reusing dataset squad (/Users/stevengeorge/.cache/huggingface/datasets/squad/plain_text/1.0.0/4fffa6cf76083860f85fa83486ec3028e7e32c342c218ff2a620fc6b2868483a)
# (10570, 5)
#                                              answers  \
# 0  {'answer_start': [177, 177, 177], 'text': ['De...
# 1  {'answer_start': [249, 249, 249], 'text': ['Ca...
# 2  {'answer_start': [403, 355, 355], 'text': ['Sa...
# 3  {'answer_start': [177, 177, 177], 'text': ['De...
# 4  {'answer_start': [488, 488, 521], 'text': ['go...
#
#                                              context  \
# 0  Super Bowl 50 was an American football game to...
# 1  Super Bowl 50 was an American football game to...
# 2  Super Bowl 50 was an American football game to...
# 3  Super Bowl 50 was an American football game to...
# 4  Super Bowl 50 was an American football game to...
#
#                          id  \
# 0  56be4db0acb8001400a502ec
# 1  56be4db0acb8001400a502ed
# 2  56be4db0acb8001400a502ee
# 3  56be4db0acb8001400a502ef
# 4  56be4db0acb8001400a502f0
#
#                                             question          title
# 0  Which NFL team represented the AFC at Super Bo...  Super_Bowl_50
# 1  Which NFL team represented the NFC at Super Bo...  Super_Bowl_50
# 2                Where did Super Bowl 50 take place?  Super_Bowl_50
# 3                  Which NFL team won Super Bowl 50?  Super_Bowl_50
# 4  What color was used to emphasize the 50th anni...  Super_Bowl_50

# %%
squad_df['id'].nunique()
# Out:
# 10570

# %%
squad_df['context_letters_only'] = squad_df['context'].apply(lambda x: re.sub(r"[^a-zA-Z]+", '', x))

# %%
combined = squad_reasoning.merge(squad_df, left_on=['Passage_letters_only', 'Question'], right_on=['context_letters_only', 'question'], how='left', indicator=True)
print(combined.shape)
combined.head()
# Out:
# (103, 15)
#                                              Passage  \
# 0  The Central Region, consisting of present-day ...
# 1  Manning finished the game 13 of 23 for 141 yar...
# 2  In business, notable alumni include Microsoft ...
# 3  Manning finished the game 13 of 23 for 141 yar...
# 4  The collection of Italian, Medieval, Renaissan...
#
#                                             Question                Answer  \
# 0           Where was the Central Secretariat based?             Khanbaliq
# 1  What is th elast name of the player who was th...              Anderson
# 2  What Goldman Sachs CEO is also an alumni of th...           Jon Corzine
# 3  How many intercpetions did Newton have in Supe...                   one
# 4  Who designed the largest item from Italy that ...  Giuliano da Sangallo
#
#        Reasoning Type RT 2  RT 3 Comments  \
# 0            Explicit  NaN   NaN      NaN
# 1            Implicit  NaN   NaN      NaN
# 2  External Knowledge  NaN   NaN      NaN
# 3            Implicit  NaN   NaN      NaN
# 4            Implicit  NaN   NaN      NaN
#
#                                 Passage_letters_only  \
# 0  TheCentralRegionconsistingofpresentdayHebeiSha...
# 1  Manningfinishedthegameofforyardswithoneinterce...
# 2  InbusinessnotablealumniincludeMicrosoftCEOSaty...
# 3  Manningfinishedthegameofforyardswithoneinterce...
# 4  ThecollectionofItalianMedievalRenaissanceBaroq...
#
#                                              answers  \
# 0  {'answer_start': [306, 306, 306], 'text': ['Kh...
# 1  {'answer_start': [155, 155, 155], 'text': ['An...
# 2  {'answer_start': [217, 217, 217], 'text': ['Jo...
# 3  {'answer_start': [54, 612, 612], 'text': ['one...
# 4  {'answer_start': [1540, 1540, 1489], 'text': [...
#
#                                              context  \
# 0  The Central Region, consisting of present-day ...
# 1  Manning finished the game 13 of 23 for 141 yar...
# 2  In business, notable alumni include Microsoft ...
# 3  Manning finished the game 13 of 23 for 141 yar...
# 4  The collection of Italian, Medieval, Renaissan...
#
#                          id  \
# 0  572885c44b864d1900164a7a
# 1  56d9ccacdc89441400fdb843
# 2  57286951ff5b5019007da211
# 3  56d9ccacdc89441400fdb845
# 4  5726fc63dd62a815002e9709
#
#                                             question  \
# 0           Where was the Central Secretariat based?
# 1  What is th elast name of the player who was th...
# 2  What Goldman Sachs CEO is also an alumni of th...
# 3  How many intercpetions did Newton have in Supe...
# 4  Who designed the largest item from Italy that ...
#
#                         title  \
# 0                Yuan_dynasty
# 1               Super_Bowl_50
# 2       University_of_Chicago
# 3               Super_Bowl_50
# 4  Victoria_and_Albert_Museum
#
#                                 context_letters_only _merge
# 0  TheCentralRegionconsistingofpresentdayHebeiSha...   both
# 1  Manningfinishedthegameofforyardswithoneinterce...   both
# 2  InbusinessnotablealumniincludeMicrosoftCEOSaty...   both
# 3  Manningfinishedthegameofforyardswithoneinterce...   both
# 4  ThecollectionofItalianMedievalRenaissanceBaroq...   both

# %%
combined['_merge'].value_counts()
# Out:
# both          103
# left_only       0
# right_only      0
# Name: _merge, dtype: int64

# %%
combined[combined[['question', 'context']].duplicated()]
# Out:
#                                               Passage  \
# 36  European Union law is a body of treaties and l...
# 76  The immune system is a system of many biologic...
# 94  Carolina suffered a major setback when Thomas ...
#
#                                              Question  \
# 36          What are the main sources of primary law?
# 76       What does the immune system protect against?
# 94  How many years has Thomas Davis played in the ...
#
#                                           Answer Reasoning Type RT 2  RT 3  \
# 36  the Treaties establishing the European Union       Explicit  NaN   NaN
# 76                                       disease       Explicit  NaN   NaN
# 94                                            11       Implicit  NaN   NaN
#
#    Comments                               Passage_letters_only  \
# 36      NaN  EuropeanUnionlawisabodyoftreatiesandlegislatio...
# 76      NaN  Theimmunesystemisasystemofmanybiologicalstruct...
# 94      NaN  CarolinasufferedamajorsetbackwhenThomasDavisan...
#
#                                               answers  \
# 36  {'answer_start': [313, 313, 313, 313], 'text':...
# 76  {'answer_start': [210, 115, 115, 107], 'text':...
# 94  {'answer_start': [56, 56, 56], 'text': ['11', ...
#
#                                               context  \
# 36  European Union law is a body of treaties and l...
# 76  The immune system is a system of many biologic...
# 94  Carolina suffered a major setback when Thomas ...
#
#                           id  \
# 36  57268b43dd62a815002e88f1
# 76  5726eb76f1498d1400e8efdb
# 94  56bf3a223aeaaa14008c9577
#
#                                              question               title  \
# 36          What are the main sources of primary law?  European_Union_law
# 76       What does the immune system protect against?       Immune_system
# 94  How many years has Thomas Davis played in the ...       Super_Bowl_50
#
#                                  context_letters_only _merge
# 36  EuropeanUnionlawisabodyoftreatiesandlegislatio...   both
# 76  Theimmunesystemisasystemofmanybiologicalstruct...   both
# 94  CarolinasufferedamajorsetbackwhenThomasDavisan...   both

# %%
squad_df[squad_df['question'] == 'What are the main sources of primary law?']
# Out:
#                                                 answers  \
# 4065  {'answer_start': [317, 313, 227, 313], 'text':...
# 4073  {'answer_start': [313, 313, 313, 313], 'text':...
#
#                                                 context  \
# 4065  European Union law is a body of treaties and l...
# 4073  European Union law is a body of treaties and l...
#
#                             id                                   question  \
# 4065  5725b7f389a1e219009abd5e  What are the main sources of primary law?
# 4073  57268b43dd62a815002e88f1  What are the main sources of primary law?
#
#                    title                               context_letters_only
# 4065  European_Union_law  EuropeanUnionlawisabodyoftreatiesandlegislatio...
# 4073  European_Union_law  EuropeanUnionlawisabodyoftreatiesandlegislatio...

# %%
combined.drop_duplicates(subset=['question', 'context'], inplace=True)
print(combined.shape)
combined.head()
# Out:
# (100, 15)
#                                              Passage  \
# 0  The Central Region, consisting of present-day ...
# 1  Manning finished the game 13 of 23 for 141 yar...
# 2  In business, notable alumni include Microsoft ...
# 3  Manning finished the game 13 of 23 for 141 yar...
# 4  The collection of Italian, Medieval, Renaissan...
#
#                                             Question                Answer  \
# 0           Where was the Central Secretariat based?             Khanbaliq
# 1  What is th elast name of the player who was th...              Anderson
# 2  What Goldman Sachs CEO is also an alumni of th...           Jon Corzine
# 3  How many intercpetions did Newton have in Supe...                   one
# 4  Who designed the largest item from Italy that ...  Giuliano da Sangallo
#
#        Reasoning Type RT 2  RT 3 Comments  \
# 0            Explicit  NaN   NaN      NaN
# 1            Implicit  NaN   NaN      NaN
# 2  External Knowledge  NaN   NaN      NaN
# 3            Implicit  NaN   NaN      NaN
# 4            Implicit  NaN   NaN      NaN
#
#                                 Passage_letters_only  \
# 0  TheCentralRegionconsistingofpresentdayHebeiSha...
# 1  Manningfinishedthegameofforyardswithoneinterce...
# 2  InbusinessnotablealumniincludeMicrosoftCEOSaty...
# 3  Manningfinishedthegameofforyardswithoneinterce...
# 4  ThecollectionofItalianMedievalRenaissanceBaroq...
#
#                                              answers  \
# 0  {'answer_start': [306, 306, 306], 'text': ['Kh...
# 1  {'answer_start': [155, 155, 155], 'text': ['An...
# 2  {'answer_start': [217, 217, 217], 'text': ['Jo...
# 3  {'answer_start': [54, 612, 612], 'text': ['one...
# 4  {'answer_start': [1540, 1540, 1489], 'text': [...
#
#                                              context  \
# 0  The Central Region, consisting of present-day ...
# 1  Manning finished the game 13 of 23 for 141 yar...
# 2  In business, notable alumni include Microsoft ...
# 3  Manning finished the game 13 of 23 for 141 yar...
# 4  The collection of Italian, Medieval, Renaissan...
#
#                          id  \
# 0  572885c44b864d1900164a7a
# 1  56d9ccacdc89441400fdb843
# 2  57286951ff5b5019007da211
# 3  56d9ccacdc89441400fdb845
# 4  5726fc63dd62a815002e9709
#
#                                             question  \
# 0           Where was the Central Secretariat based?
# 1  What is th elast name of the player who was th...
# 2  What Goldman Sachs CEO is also an alumni of th...
# 3  How many intercpetions did Newton have in Supe...
# 4  Who designed the largest item from Italy that ...
#
#                         title  \
# 0                Yuan_dynasty
# 1               Super_Bowl_50
# 2       University_of_Chicago
# 3               Super_Bowl_50
# 4  Victoria_and_Albert_Museum
#
#                                 context_letters_only _merge
# 0  TheCentralRegionconsistingofpresentdayHebeiSha...   both
# 1  Manningfinishedthegameofforyardswithoneinterce...   both
# 2  InbusinessnotablealumniincludeMicrosoftCEOSaty...   both
# 3  Manningfinishedthegameofforyardswithoneinterce...   both
# 4  ThecollectionofItalianMedievalRenaissanceBaroq...   both

# %%
combined = combined[list(squad_reasoning.columns) + ['id']]
combined.head()
# Out:
#                                              Passage  \
# 0  The Central Region, consisting of present-day ...
# 1  Manning finished the game 13 of 23 for 141 yar...
# 2  In business, notable alumni include Microsoft ...
# 3  Manning finished the game 13 of 23 for 141 yar...
# 4  The collection of Italian, Medieval, Renaissan...
#
#                                             Question                Answer  \
# 0           Where was the Central Secretariat based?             Khanbaliq
# 1  What is th elast name of the player who was th...              Anderson
# 2  What Goldman Sachs CEO is also an alumni of th...           Jon Corzine
# 3  How many intercpetions did Newton have in Supe...                   one
# 4  Who designed the largest item from Italy that ...  Giuliano da Sangallo
#
#        Reasoning Type RT 2  RT 3 Comments  \
# 0            Explicit  NaN   NaN      NaN
# 1            Implicit  NaN   NaN      NaN
# 2  External Knowledge  NaN   NaN      NaN
# 3            Implicit  NaN   NaN      NaN
# 4            Implicit  NaN   NaN      NaN
#
#                                 Passage_letters_only                        id
# 0  TheCentralRegionconsistingofpresentdayHebeiSha...  572885c44b864d1900164a7a
# 1  Manningfinishedthegameofforyardswithoneinterce...  56d9ccacdc89441400fdb843
# 2  InbusinessnotablealumniincludeMicrosoftCEOSaty...  57286951ff5b5019007da211
# 3  Manningfinishedthegameofforyardswithoneinterce...  56d9ccacdc89441400fdb845
# 4  ThecollectionofItalianMedievalRenaissanceBaroq...  5726fc63dd62a815002e9709

# %%
combined['Reasoning Type'].value_counts()
# Out:
# Explicit              55
# Paraphrasing          15
# Co-reference          13
# Implicit              10
# External Knowledge     5
# Multi-hop              2
# Name: Reasoning Type, dtype: int64

# %%
combined_expanded = pd.melt(combined, id_vars='id', value_vars=['Reasoning Type', 'RT 2', 'RT 3']).sort_values('id')
print(combined_expanded.shape)
combined_expanded.head()
# Out:
# (300, 3)
#                            id        variable     value
# 291  56beb7fd3aeaaa14008c92b8            RT 3       NaN
# 191  56beb7fd3aeaaa14008c92b8            RT 2       NaN
# 91   56beb7fd3aeaaa14008c92b8  Reasoning Type  Implicit
# 195  56bebad93aeaaa14008c92fb            RT 2       NaN
# 295  56bebad93aeaaa14008c92fb            RT 3       NaN

# %%
combined_expanded.drop('variable', axis=1, inplace=True)
combined_expanded.dropna(subset=['value'], inplace=True)
combined_expanded.reset_index(drop=True, inplace=True)
combined_expanded['dataset'] = 'squad'
print(combined_expanded.shape)
combined_expanded.head()
# Out:
# (112, 3)
#                          id               value dataset
# 0  56beb7fd3aeaaa14008c92b8            Implicit   squad
# 1  56bebad93aeaaa14008c92fb        Paraphrasing   squad
# 2  56d723560d65d214001983ac            Explicit   squad
# 3  56d9943fdc89441400fdb577            Explicit   squad
# 4  56d9c92bdc89441400fdb811  External Knowledge   squad

# %%
combined_expanded['value'].value_counts()
# Out:
# Explicit              57
# Co-reference          17
# Paraphrasing          17
# Implicit              10
# External Knowledge     8
# Multi-hop              2
# Temporal               1
# Name: value, dtype: int64

# %% [markdown]
# ## AdversarialQA

# %%
reasoning_df = pd.DataFrame()

for dataset in ['DBERT', 'DBiDAF', 'DRoBERTa']:
    
    df = pd.read_csv(f'data/external/Reasoning Types/{dataset}.csv')
    df['dataset'] = dataset
    print(dataset)
    print(df.shape)
    reasoning_df = reasoning_df.append(df)

print(reasoning_df.shape)
reasoning_df.head()
# Out:
# DBERT
# (100, 8)
# DBiDAF
# (100, 8)
# DRoBERTa
# (100, 8)
# (300, 8)
#                                              Passage  \
# 0  The simplest valve gears give events of fixed ...
# 1  Natural killer cells, or NK cells, are a compo...
# 2  In economics, notable Nobel Memorial Prize in ...
# 3  The flagship stations of each station in the m...
# 4  The Maroons compete in the NCAA's Division III...
#
#                                             Question  \
# 0                Engines move in a circle called an?
# 1  How do NK cells recognize tumor and infected c...
# 2      Samuelson is from the country of what leader?
# 3  What station is not based in the state of the ...
# 4    Who was the first winner of the Heisman Trophy?
#
#                                               Answer      Reasoning Type  \
# 0                                       engine cycle        Paraphrasing
# 1  the MHC makeup on the surface of those cells i...           Multi-hop
# 2                                      Ronald Reagan           Multi-hop
# 3                                   WBT-FM (99.3 FM)  External Knowledge
# 4                    Chicago Maroons football player            Explicit
#
#            RT 2 RT 3 Comments dataset
# 0           NaN  NaN      NaN   DBERT
# 1  Co-reference  NaN      NaN   DBERT
# 2           NaN  NaN      NaN   DBERT
# 3           NaN  NaN      NaN   DBERT
# 4           NaN  NaN      NaN   DBERT

# %%
all_datasets_df = pd.DataFrame()

for dataset in ['dbert', 'droberta', 'dbidaf']:
    
    dataset_df = pd.DataFrame()
    
    for split in ['train', 'validation', 'test']:
        split_data = load_dataset("adversarial_qa", dataset, split=split)
        split_df = pd.DataFrame(split_data)
        split_df['split'] = split
        dataset_df = dataset_df.append(split_df)
    
    dataset_df['dataset'] = dataset
    print(dataset)
    print(dataset_df.shape)
    print('\n')
    
    all_datasets_df = all_datasets_df.append(dataset_df)
# Out:
# Reusing dataset adversarial_qa (/Users/stevengeorge/.cache/huggingface/datasets/adversarial_qa/dbert/1.0.0/2f8c1f6e146e203b3fde4b73427f19abf4ab44f315df4ccd7613f03caf3c2971)
# Reusing dataset adversarial_qa (/Users/stevengeorge/.cache/huggingface/datasets/adversarial_qa/dbert/1.0.0/2f8c1f6e146e203b3fde4b73427f19abf4ab44f315df4ccd7613f03caf3c2971)
# Reusing dataset adversarial_qa (/Users/stevengeorge/.cache/huggingface/datasets/adversarial_qa/dbert/1.0.0/2f8c1f6e146e203b3fde4b73427f19abf4ab44f315df4ccd7613f03caf3c2971)
# dbert
# (12000, 8)
# Reusing dataset adversarial_qa (/Users/stevengeorge/.cache/huggingface/datasets/adversarial_qa/droberta/1.0.0/2f8c1f6e146e203b3fde4b73427f19abf4ab44f315df4ccd7613f03caf3c2971)
# Reusing dataset adversarial_qa (/Users/stevengeorge/.cache/huggingface/datasets/adversarial_qa/droberta/1.0.0/2f8c1f6e146e203b3fde4b73427f19abf4ab44f315df4ccd7613f03caf3c2971)
# Reusing dataset adversarial_qa (/Users/stevengeorge/.cache/huggingface/datasets/adversarial_qa/droberta/1.0.0/2f8c1f6e146e203b3fde4b73427f19abf4ab44f315df4ccd7613f03caf3c2971)
# droberta
# (12000, 8)
# Reusing dataset adversarial_qa (/Users/stevengeorge/.cache/huggingface/datasets/adversarial_qa/dbidaf/1.0.0/2f8c1f6e146e203b3fde4b73427f19abf4ab44f315df4ccd7613f03caf3c2971)
# Reusing dataset adversarial_qa (/Users/stevengeorge/.cache/huggingface/datasets/adversarial_qa/dbidaf/1.0.0/2f8c1f6e146e203b3fde4b73427f19abf4ab44f315df4ccd7613f03caf3c2971)
# Reusing dataset adversarial_qa (/Users/stevengeorge/.cache/huggingface/datasets/adversarial_qa/dbidaf/1.0.0/2f8c1f6e146e203b3fde4b73427f19abf4ab44f315df4ccd7613f03caf3c2971)
# dbidaf
# (12000, 8)

# %%
all_datasets_df['split'].value_counts()
# Out:
# train         30000
# test           3000
# validation     3000
# Name: split, dtype: int64

# %%
reasoning_df.merge(all_datasets_df, left_on='Question', right_on='question').shape
# Out:
# (98, 16)

# %%
reasoning_df.merge(all_datasets_df, left_on='Passage', right_on='context').shape
# Out:
# (933, 16)

# %% [markdown]
# Format questions and contexts (remove non-letters, lowercase and strip whitespace)

# %%
reasoning_df['Question_fmt'] = reasoning_df['Question'].apply(lambda x: x.lower().strip())
reasoning_df['Passage_fmt'] = reasoning_df['Passage'].apply(lambda x: x.lower().strip())

reasoning_df['Passage_fmt'] = reasoning_df['Passage_fmt'].apply(lambda x: re.sub(r"[^a-zA-Z]+", '', x))
reasoning_df['Question_fmt'] = reasoning_df['Question_fmt'].apply(lambda x: re.sub(r"[^a-zA-Z]+", '', x))

# %%
all_datasets_df['question_fmt'] = all_datasets_df['question'].apply(lambda x: x.lower().strip())
all_datasets_df['context_fmt'] = all_datasets_df['context'].apply(lambda x: x.lower().strip())

all_datasets_df['context_fmt'] = all_datasets_df['context_fmt'].apply(lambda x: re.sub(r"[^a-zA-Z]+", '', x))
all_datasets_df['question_fmt'] = all_datasets_df['question_fmt'].apply(lambda x: re.sub(r"[^a-zA-Z]+", '', x))

# %%
reasoning_df.shape
# Out:
# (300, 10)

# %% [markdown]
# 1. See contexts in common

# %%
reasoning_df_contexts = reasoning_df.copy()[['Passage_fmt']]
reasoning_df_contexts.rename(columns={'Passage_fmt': 'context_fmt'}, inplace=True)
reasoning_df_contexts.drop_duplicates(inplace=True)
print(reasoning_df_contexts.shape)
reasoning_df_contexts.head()
# Out:
# (114, 1)
#                                          context_fmt
# 0  thesimplestvalvegearsgiveeventsoffixedlengthdu...
# 1  naturalkillercellsornkcellsareacomponentofthei...
# 2  ineconomicsnotablenobelmemorialprizeineconomic...
# 3  theflagshipstationsofeachstationinthemarketsof...
# 4  themaroonscompeteinthencaasdivisioniiiasmember...

# %%
print(all_datasets_df.shape)
all_datasets_df_contexts = all_datasets_df.copy()[['context_fmt']]
all_datasets_df_contexts.drop_duplicates(inplace=True)
print(all_datasets_df_contexts.shape)
all_datasets_df_contexts.head()
# Out:
# (36000, 10)
# (3473, 1)
#                                           context_fmt
# 0   agenerationlatertheirishanglicanbishopgeorgebe...
# 5   humemaintainedthatallknowledgeeventhemostbasic...
# 8   philosophicalempiricistsholdnoknowledgetobepro...
# 13  inthelatethandearlythcenturyseveralformsofprag...
# 17  millsempiricismthusheldthatknowledgeofanykindi...

# %%
combined = reasoning_df_contexts.merge(all_datasets_df_contexts, on='context_fmt', how='left', indicator=True)
print(combined.shape)
combined.head()
# Out:
# (114, 2)
#                                          context_fmt _merge
# 0  thesimplestvalvegearsgiveeventsoffixedlengthdu...   both
# 1  naturalkillercellsornkcellsareacomponentofthei...   both
# 2  ineconomicsnotablenobelmemorialprizeineconomic...   both
# 3  theflagshipstationsofeachstationinthemarketsof...   both
# 4  themaroonscompeteinthencaasdivisioniiiasmember...   both

# %%
combined['_merge'].value_counts()
# Out:
# both          112
# left_only       2
# right_only      0
# Name: _merge, dtype: int64

# %%
combined[combined['_merge'] == 'left_only'].head()
# Out:
#                                           context_fmt     _merge
# 78  theinvertedrepeatregionsarehighlyconservedamon...  left_only
# 88  theroleofteacherisoftenformalandongoingcarried...  left_only

# %%
reasoning_df[reasoning_df['Passage_fmt'].isin(combined[combined['_merge'] == 'left_only']['context_fmt'])]
# Out:
#                                               Passage  \
# 13  The inverted repeat regions are highly conserv...
# 39  The role of teacher is often formal and ongoin...
# 54  The inverted repeat regions are highly conserv...
# 90  The role of teacher is often formal and ongoin...
# 48  The inverted repeat regions are highly conserv...
# 83  The inverted repeat regions are highly conserv...
#
#                                              Question  \
# 13                What came prior to the chloroplast?
# 39  What might be an area of study needed to becom...
# 54                             Which is changed more?
# 90  What do teachers have in common with other pro...
# 48       What are the two lineages and genome called?
# 83                      What is the chloroplast only?
#
#                                                Answer Reasoning Type  \
# 13                                      cyanobacteria   Paraphrasing
# 39                                           pedagogy   Co-reference
# 54  chloroplast DNAs which have lost some of the i...    Comparative
# 90                           professional development   Paraphrasing
# 48  Similar inverted repeats exist in the genomes ...            NaN
# 83                                         suggesting            NaN
#
#             RT 2 RT 3      Comments   dataset  \
# 13           NaN  NaN           NaN    DBiDAF
# 39           NaN  NaN           NaN    DBiDAF
# 54  Paraphrasing  NaN           NaN    DBiDAF
# 90           NaN  NaN           NaN    DBiDAF
# 48           NaN  NaN  Bad question  DRoBERTa
# 83           NaN  NaN  Bad question  DRoBERTa
#
#                                         Question_fmt  \
# 13                     whatcamepriortothechloroplast
# 39    whatmightbeanareaofstudyneededtobecomeateacher
# 54                                whichischangedmore
# 90  whatdoteachershaveincommonwithotherprofessionals
# 48              whatarethetwolineagesandgenomecalled
# 83                          whatisthechloroplastonly
#
#                                           Passage_fmt
# 13  theinvertedrepeatregionsarehighlyconservedamon...
# 39  theroleofteacherisoftenformalandongoingcarried...
# 54  theinvertedrepeatregionsarehighlyconservedamon...
# 90  theroleofteacherisoftenformalandongoingcarried...
# 48  theinvertedrepeatregionsarehighlyconservedamon...
# 83  theinvertedrepeatregionsarehighlyconservedamon...

# %%
reasoning_df[reasoning_df['Passage_fmt'].isin(combined[combined['_merge'] == 'left_only']['context_fmt'])]['Passage'].iloc[0]
# Out:
# 'The inverted repeat regions are highly conserved among land plants, and accumulate few mutations. Similar inverted repeats exist in the genomes of cyanobacteria and the other two chloroplast lineages (glaucophyta and rhodophyceæ), suggesting that they predate the chloroplast, though some chloroplast DNAs have since lost or flipped the inverted repeats (making them direct repeats). It is possible that the inverted repeats help stabilize the rest of the chloroplast genome, as chloroplast DNAs which have lost some of the inverted repeat segments tend to get rearranged more.'

# %%
reasoning_df[reasoning_df['Passage_fmt'].isin(combined[combined['_merge'] == 'left_only']['context_fmt'])]['Passage_fmt'].iloc[0]
# Out:
# '...'

# %%
all_datasets_df[all_datasets_df['context'].apply(lambda x: 'The inverted repeat regions' in x)]
# Out:
# Empty DataFrame
# Columns: [answers, context, id, metadata, question, title, split, dataset, question_fmt, context_fmt]
# Index: []

# %%
all_datasets_df[all_datasets_df['context'].apply(lambda x: 'The role of teacher' in x)]
# Out:
# Empty DataFrame
# Columns: [answers, context, id, metadata, question, title, split, dataset, question_fmt, context_fmt]
# Index: []

# %% [markdown]
# 2. See questions in common

# %%
reasoning_df.shape
# Out:
# (300, 10)

# %%
reasoning_df_questions = reasoning_df.copy()[['Question_fmt']]
reasoning_df_questions.rename(columns={'Question_fmt': 'question_fmt'}, inplace=True)
reasoning_df_questions.drop_duplicates(inplace=True)
print(reasoning_df_questions.shape)
reasoning_df_questions.head()
# Out:
# (300, 1)
#                                         question_fmt
# 0                       enginesmoveinacirclecalledan
# 1         howdonkcellsrecognizetumorandinfectedcells
# 2              samuelsonisfromthecountryofwhatleader
# 3  whatstationisnotbasedinthestateoftheteamwhoseg...
# 4             whowasthefirstwinneroftheheismantrophy

# %%
print(all_datasets_df.shape)
all_datasets_df_questions = all_datasets_df.copy()[['question_fmt']]
all_datasets_df_questions.drop_duplicates(inplace=True)
print(all_datasets_df_questions.shape)
all_datasets_df_questions.head()
# Out:
# (36000, 10)
# (35009, 1)
#                        question_fmt
# 0        whatconceptismentionedlast
# 1       whatconceptismentionedfirst
# 2          whatgroupismentionedlast
# 3   whattimeperiodismentionedsecond
# 4  whatworkofwritingismentionedlast

# %%
combined = reasoning_df_questions.merge(all_datasets_df_questions, on='question_fmt', how='left', indicator=True)
print(combined.shape)
combined.head()
# Out:
# (300, 2)
#                                         question_fmt     _merge
# 0                       enginesmoveinacirclecalledan  left_only
# 1         howdonkcellsrecognizetumorandinfectedcells  left_only
# 2              samuelsonisfromthecountryofwhatleader  left_only
# 3  whatstationisnotbasedinthestateoftheteamwhoseg...  left_only
# 4             whowasthefirstwinneroftheheismantrophy  left_only

# %%
combined['_merge'].value_counts()
# Out:
# left_only     198
# both          102
# right_only      0
# Name: _merge, dtype: int64

# %%
combined[combined['_merge'] == 'left_only'].head()
# Out:
#                                         question_fmt     _merge
# 0                       enginesmoveinacirclecalledan  left_only
# 1         howdonkcellsrecognizetumorandinfectedcells  left_only
# 2              samuelsonisfromthecountryofwhatleader  left_only
# 3  whatstationisnotbasedinthestateoftheteamwhoseg...  left_only
# 4             whowasthefirstwinneroftheheismantrophy  left_only

# %%
reasoning_df[reasoning_df['Question_fmt'].isin(combined[combined['_merge'] == 'left_only']['question_fmt'])]
# Out:
#                                               Passage  \
# 0   The simplest valve gears give events of fixed ...
# 1   Natural killer cells, or NK cells, are a compo...
# 2   In economics, notable Nobel Memorial Prize in ...
# 3   The flagship stations of each station in the m...
# 4   The Maroons compete in the NCAA's Division III...
# ..                                                ...
# 89  A method to lessen the magnitude of this heati...
# 90  East and Central Africa's biggest economy has ...
# 93  Natural killer cells, or NK cells, are a compo...
# 94  Years before his death, Genghis Khan asked to ...
# 95  In July 2013, the English High Court of Justic...
#
#                                              Question  \
# 0                 Engines move in a circle called an?
# 1   How do NK cells recognize tumor and infected c...
# 2       Samuelson is from the country of what leader?
# 3   What station is not based in the state of the ...
# 4     Who was the first winner of the Heisman Trophy?
# ..                                                ...
# 89  What is unique about the Woolf high-pressure c...
# 90  How has the economy in East and Central Africa...
# 93                    Host cells can be destroyed by?
# 94        The Genghis Khan Mausoleum does not have a?
# 95  What kind of terms did the two companies agree...
#
#                                                Answer      Reasoning Type  \
# 0                                        engine cycle        Paraphrasing
# 1   the MHC makeup on the surface of those cells i...           Multi-hop
# 2                                       Ronald Reagan           Multi-hop
# 3                                    WBT-FM (99.3 FM)  External Knowledge
# 4                     Chicago Maroons football player            Explicit
# ..                                                ...                 ...
# 89                     less heat is lost by the steam           Multi-hop
# 90  rapid expansion in telecommunication and finan...        Paraphrasing
# 93                               Natural killer cells           Multi-hop
# 94                                               body           Multi-hop
# 95                                       confidential        Paraphrasing
#
#             RT 2 RT 3 Comments   dataset  \
# 0            NaN  NaN      NaN     DBERT
# 1   Co-reference  NaN      NaN     DBERT
# 2            NaN  NaN      NaN     DBERT
# 3            NaN  NaN      NaN     DBERT
# 4            NaN  NaN      NaN     DBERT
# ..           ...  ...      ...       ...
# 89           NaN  NaN      NaN  DRoBERTa
# 90           NaN  NaN      NaN  DRoBERTa
# 93           NaN  NaN      NaN  DRoBERTa
# 94      Negation  NaN      NaN  DRoBERTa
# 95           NaN  NaN      NaN  DRoBERTa
#
#                                          Question_fmt  \
# 0                        enginesmoveinacirclecalledan
# 1          howdonkcellsrecognizetumorandinfectedcells
# 2               samuelsonisfromthecountryofwhatleader
# 3   whatstationisnotbasedinthestateoftheteamwhoseg...
# 4              whowasthefirstwinneroftheheismantrophy
# ..                                                ...
# 89  whatisuniqueaboutthewoolfhighpressurecompounde...
# 90        howhastheeconomyineastandcentralafricagrown
# 93                          hostcellscanbedestroyedby
# 94                thegenghiskhanmausoleumdoesnothavea
# 95           whatkindoftermsdidthetwocompaniesagreeto
#
#                                           Passage_fmt
# 0   thesimplestvalvegearsgiveeventsoffixedlengthdu...
# 1   naturalkillercellsornkcellsareacomponentofthei...
# 2   ineconomicsnotablenobelmemorialprizeineconomic...
# 3   theflagshipstationsofeachstationinthemarketsof...
# 4   themaroonscompeteinthencaasdivisioniiiasmember...
# ..                                                ...
# 89  amethodtolessenthemagnitudeofthisheatingandcoo...
# 90  eastandcentralafricasbiggesteconomyhaspostedtr...
# 93  naturalkillercellsornkcellsareacomponentofthei...
# 94  yearsbeforehisdeathgenghiskhanaskedtobeburiedw...
# 95  injulytheenglishhighcourtofjusticefoundthatmic...
#
# [198 rows x 10 columns]

# %%
reasoning_df[reasoning_df['Question_fmt'].isin(combined[combined['_merge'] == 'left_only']['question_fmt'])]['Question'].iloc[0]
# Out:
# 'Engines move in a circle called an?'

# %%
reasoning_df[reasoning_df['Question_fmt'].isin(combined[combined['_merge'] == 'left_only']['question_fmt'])]['Question_fmt'].iloc[0]
# Out:
# 'enginesmoveinacirclecalledan'

# %%
all_datasets_df[all_datasets_df['question'].apply(lambda x: 'engines move' in x)]
# Out:
# Empty DataFrame
# Columns: [answers, context, id, metadata, question, title, split, dataset, question_fmt, context_fmt]
# Index: []

# %%
all_datasets_df[all_datasets_df['question'].apply(lambda x: 'Genghis Khan Mausoleum' in x)]
# Out:
# Empty DataFrame
# Columns: [answers, context, id, metadata, question, title, split, dataset, question_fmt, context_fmt]
# Index: []

# %% [markdown]
# 3. Combine on context _and_ question

# %%
all_datasets_df.head()
# Out:
#                                              answers  \
# 0  {'answer_start': [742], 'text': ['subjective i...
# 1       {'answer_start': [159], 'text': ['atheism']}
# 2        {'answer_start': [614], 'text': ['humans']}
# 3          {'answer_start': [265], 'text': ['1710']}
# 4     {'answer_start': [568], 'text': ['Alciphron']}
#
#                                              context  \
# 0  A generation later, the Irish Anglican bishop,...
# 1  A generation later, the Irish Anglican bishop,...
# 2  A generation later, the Irish Anglican bishop,...
# 3  A generation later, the Irish Anglican bishop,...
# 4  A generation later, the Irish Anglican bishop,...
#
#                                          id  \
# 0  dab017ed8a1c27c6afa2d8618abc3a477a4edffc
# 1  2fb55cf1439a1a50ee47193124d86c03bf5d5128
# 2  7b26ca94c04cd61cf1aaed8a5ed1039be4981041
# 3  2e8a1099995928e2cb9910c6f3e9b21ce4f50016
# 4  50b7401b594883ee57661f2fdda6ac264b64ca56
#
#                                             metadata  \
# 0  {'split': 'train', 'model_in_the_loop': 'BERT-...
# 1  {'split': 'train', 'model_in_the_loop': 'BERT-...
# 2  {'split': 'train', 'model_in_the_loop': 'BERT-...
# 3  {'split': 'train', 'model_in_the_loop': 'BERT-...
# 4  {'split': 'train', 'model_in_the_loop': 'BERT-...
#
#                                   question       title  split dataset  \
# 0          what concept is mentioned last?  Empiricism  train   dbert
# 1         what concept is mentioned first?  Empiricism  train   dbert
# 2            what group is mentioned last?  Empiricism  train   dbert
# 3    what time period is mentioned second?  Empiricism  train   dbert
# 4  what work of writing is mentioned last?  Empiricism  train   dbert
#
#                        question_fmt  \
# 0        whatconceptismentionedlast
# 1       whatconceptismentionedfirst
# 2          whatgroupismentionedlast
# 3   whattimeperiodismentionedsecond
# 4  whatworkofwritingismentionedlast
#
#                                          context_fmt
# 0  agenerationlatertheirishanglicanbishopgeorgebe...
# 1  agenerationlatertheirishanglicanbishopgeorgebe...
# 2  agenerationlatertheirishanglicanbishopgeorgebe...
# 3  agenerationlatertheirishanglicanbishopgeorgebe...
# 4  agenerationlatertheirishanglicanbishopgeorgebe...

# %%
combined = reasoning_df.merge(all_datasets_df, left_on=['Question_fmt', 'Passage_fmt'], right_on=['question_fmt', 'context_fmt'], how='left', indicator=True, suffixes=('_reasoning', '_datasets'))
print(combined.shape)
combined.head()
# Out:
# (300, 21)
#                                              Passage  \
# 0  The simplest valve gears give events of fixed ...
# 1  Natural killer cells, or NK cells, are a compo...
# 2  In economics, notable Nobel Memorial Prize in ...
# 3  The flagship stations of each station in the m...
# 4  The Maroons compete in the NCAA's Division III...
#
#                                             Question  \
# 0                Engines move in a circle called an?
# 1  How do NK cells recognize tumor and infected c...
# 2      Samuelson is from the country of what leader?
# 3  What station is not based in the state of the ...
# 4    Who was the first winner of the Heisman Trophy?
#
#                                               Answer      Reasoning Type  \
# 0                                       engine cycle        Paraphrasing
# 1  the MHC makeup on the surface of those cells i...           Multi-hop
# 2                                      Ronald Reagan           Multi-hop
# 3                                   WBT-FM (99.3 FM)  External Knowledge
# 4                    Chicago Maroons football player            Explicit
#
#            RT 2 RT 3 Comments dataset_reasoning  \
# 0           NaN  NaN      NaN             DBERT
# 1  Co-reference  NaN      NaN             DBERT
# 2           NaN  NaN      NaN             DBERT
# 3           NaN  NaN      NaN             DBERT
# 4           NaN  NaN      NaN             DBERT
#
#                                         Question_fmt  \
# 0                       enginesmoveinacirclecalledan
# 1         howdonkcellsrecognizetumorandinfectedcells
# 2              samuelsonisfromthecountryofwhatleader
# 3  whatstationisnotbasedinthestateoftheteamwhoseg...
# 4             whowasthefirstwinneroftheheismantrophy
#
#                                          Passage_fmt answers context   id  \
# 0  thesimplestvalvegearsgiveeventsoffixedlengthdu...     NaN     NaN  NaN
# 1  naturalkillercellsornkcellsareacomponentofthei...     NaN     NaN  NaN
# 2  ineconomicsnotablenobelmemorialprizeineconomic...     NaN     NaN  NaN
# 3  theflagshipstationsofeachstationinthemarketsof...     NaN     NaN  NaN
# 4  themaroonscompeteinthencaasdivisioniiiasmember...     NaN     NaN  NaN
#
#   metadata question title split dataset_datasets question_fmt context_fmt  \
# 0      NaN      NaN   NaN   NaN              NaN          NaN         NaN
# 1      NaN      NaN   NaN   NaN              NaN          NaN         NaN
# 2      NaN      NaN   NaN   NaN              NaN          NaN         NaN
# 3      NaN      NaN   NaN   NaN              NaN          NaN         NaN
# 4      NaN      NaN   NaN   NaN              NaN          NaN         NaN
#
#       _merge
# 0  left_only
# 1  left_only
# 2  left_only
# 3  left_only
# 4  left_only

# %%
combined['_merge'].value_counts()
# Out:
# left_only     198
# both          102
# right_only      0
# Name: _merge, dtype: int64
