# %%
import os
import logging

import pandas as pd
import numpy as np
from tqdm import tqdm
from datasets import load_dataset, load_metric

# %%
os.getcwd()
# Out:
# '/SAN/intelsys/rclearn/when-do-reading-comprehension-models-learn/notebooks/exploration'

# %%
os.chdir('../..')

# %%
from src.analysis.generate_plot_data import generate_predictions_df
from src.analysis.utils import load_squadv1_dev_as_df

# %%
predictions_df = generate_predictions_df('predictions/albert-xlarge-v2-squadv1-adversarialall-wu=100-lr=3e5-bs=32-msl=384-seed=27-dbert', seed=27)
print(predictions_df.shape)
predictions_df.head()
# Out:
# 2021-08-03 23:51:25,004 - Loading predictions data
# (120000, 4)
#                                          id  \
# 0  21a3561031f2e909338196601f5c1ac2e08905b6
# 1  b6a71a728a35506dd4cd2179c9342acf5e1a047a
# 2  6febf2fec8ae1b105a1b955897415fea4b2c0c28
# 3  53e4ce951aeab3a2712aa0966d73ec3e2c62ca11
# 4  a0a308febc5e9edf56fe63556cf20c039c3fdaca
#
#                                      prediction_text  checkpoint  seed
# 0      , twice the figure for the average profession           1    27
# 1                                              empty           1    27
# 2                                              empty           1    27
# 3  42% of UK teachers experienced occupational st...           1    27
# 4                                              empty           1    27

# %%
def load_adversarial_dev_as_df(dmodel):
    logging.info(f"Loading {dmodel} dev data as DataFrame")
    adversarial_val = load_dataset('adversarial_qa', dmodel, split='validation')

    adversarial_val_df = pd.DataFrame(adversarial_val)

    logging.info(adversarial_val_df.shape)
    logging.info(adversarial_val_df.head())

    return adversarial_val_df

# %%
# %%capture
labels_df = load_adversarial_dev_as_df('droberta')
# Out:
# 2021-08-04 00:01:49,856 - Loading droberta dev data as DataFrame
# 2021-08-04 00:01:50,601 - generating examples from = /home/sgeorge/.cache/huggingface/datasets/downloads/extracted/d105f181804f029a5ff71394c53a0f314901baabcade805bcc4d5e04ccd37a7e/3_droberta/train.json
# 2021-08-04 00:01:51,799 - generating examples from = /home/sgeorge/.cache/huggingface/datasets/downloads/extracted/d105f181804f029a5ff71394c53a0f314901baabcade805bcc4d5e04ccd37a7e/3_droberta/dev.json
# 2021-08-04 00:01:51,949 - generating examples from = /home/sgeorge/.cache/huggingface/datasets/downloads/extracted/d105f181804f029a5ff71394c53a0f314901baabcade805bcc4d5e04ccd37a7e/3_droberta/test.json
# 2021-08-04 00:01:52,230 - (1000, 6)
# 2021-08-04 00:01:52,231 -                                          answers  \
# 0  {'text': ['soybeans'], 'answer_start': [386]}
# 1    {'text': ['Brazil'], 'answer_start': [338]}
# 2   {'text': ['logging'], 'answer_start': [720]}
# 3     {'text': ['Water'], 'answer_start': [139]}
# 4     {'text': ['water'], 'answer_start': [211]}
#
#                                              context  \
# 0  Between 1991 and 2000, the total area of fores...
# 1  Between 1991 and 2000, the total area of fores...
# 2  Between 1991 and 2000, the total area of fores...
# 3  During the mid-Eocene, it is believed that the...
# 4  During the mid-Eocene, it is believed that the...
#
#                                          id  \
# 0  0622161680ff6c97fa14a25b01a4bf3bc289d72f
# 1  2036cc32529c26ee87dc04a80d2d46377958cf3b
# 2  28bbcb18b5ee391a6ef522bbaae90c2c100012e3
# 3  33c1a730fc277f013ef8bf12919c0a1594b673cd
# 4  230c5c5167792912fb20128117565f2f2afb51ce
#
#                                             metadata  \
# 0  {'split': 'validation', 'model_in_the_loop': '...
# 1  {'split': 'validation', 'model_in_the_loop': '...
# 2  {'split': 'validation', 'model_in_the_loop': '...
# 3  {'split': 'validation', 'model_in_the_loop': '...
# 4  {'split': 'validation', 'model_in_the_loop': '...
#
#                                             question              title
# 0  What consumer product are the rain forests cle...  Amazon_rainforest
# 1  Of the two countries that produce soybeans, wh...  Amazon_rainforest
# 2                    How is the rain forest cleared?  Amazon_rainforest
# 3                                  The Atlantic has?  Amazon_rainforest
# 4                                   The Pacific has?  Amazon_rainforest

# %%
combined = predictions_df.merge(labels_df, on='id', how='inner')
print(combined.shape)
combined.head()
# Out:
# (120000, 9)
#                                          id  \
# 0  21a3561031f2e909338196601f5c1ac2e08905b6
# 1  21a3561031f2e909338196601f5c1ac2e08905b6
# 2  21a3561031f2e909338196601f5c1ac2e08905b6
# 3  21a3561031f2e909338196601f5c1ac2e08905b6
# 4  21a3561031f2e909338196601f5c1ac2e08905b6
#
#                                  prediction_text  checkpoint  seed  \
# 0  , twice the figure for the average profession           1    27
# 1  , twice the figure for the average profession           2    27
# 2  , twice the figure for the average profession           3    27
# 3  , twice the figure for the average profession           4    27
# 4                         the average profession           5    27
#
#                                              answers  \
# 0  {'text': ['average profession'], 'answer_start...
# 1  {'text': ['average profession'], 'answer_start...
# 2  {'text': ['average profession'], 'answer_start...
# 3  {'text': ['average profession'], 'answer_start...
# 4  {'text': ['average profession'], 'answer_start...
#
#                                              context  \
# 0  A 2000 study found that 42% of UK teachers exp...
# 1  A 2000 study found that 42% of UK teachers exp...
# 2  A 2000 study found that 42% of UK teachers exp...
# 3  A 2000 study found that 42% of UK teachers exp...
# 4  A 2000 study found that 42% of UK teachers exp...
#
#                                             metadata  \
# 0  {'split': 'validation', 'model_in_the_loop': '...
# 1  {'split': 'validation', 'model_in_the_loop': '...
# 2  {'split': 'validation', 'model_in_the_loop': '...
# 3  {'split': 'validation', 'model_in_the_loop': '...
# 4  {'split': 'validation', 'model_in_the_loop': '...
#
#                                          question    title
# 0  What is teaching not considered due to stress?  Teacher
# 1  What is teaching not considered due to stress?  Teacher
# 2  What is teaching not considered due to stress?  Teacher
# 3  What is teaching not considered due to stress?  Teacher
# 4  What is teaching not considered due to stress?  Teacher

# %%
combined = combined.head(100)

# %%
from src.analysis.utils import squad2_evaluation, squad1_evaluation

# %%
# %%time
metric_list = []

for _, row in tqdm(combined.iterrows(), total=combined.shape[0]):
    metrics = squad1_evaluation(
        row[['id']], 
        row[['prediction_text']],
        row[['answers']]
    )
    metrics['id'] = row['id']
    metric_list.append(metrics)
# Out:
#   0%|          | 0/100 [00:00<?, ?it/s]2021-08-03 23:51:28,477 - Removing /home/sgeorge/.cache/huggingface/metrics/squad/default/default_experiment-1-0.arrow
# 2021-08-03 23:51:28,487 - Removing /home/sgeorge/.cache/huggingface/metrics/squad/default/default_experiment-1-0.arrow
# 2021-08-03 23:51:28,497 - Removing /home/sgeorge/.cache/huggingface/metrics/squad/default/default_experiment-1-0.arrow
# 2021-08-03 23:51:28,506 - Removing /home/sgeorge/.cache/huggingface/metrics/squad/default/default_experiment-1-0.arrow
# 2021-08-03 23:51:28,516 - Removing /home/sgeorge/.cache/huggingface/metrics/squad/default/default_experiment-1-0.arrow
# 2021-08-03 23:51:28,543 - Removing /home/sgeorge/.cache/huggingface/metrics/squad/default/default_experiment-1-0.arrow
# 2021-08-03 23:51:28,557 - Removing /home/sgeorge/.cache/huggingface/metrics/squad/default/default_experiment-1-0.arrow
# 2021-08-03 23:51:28,570 - Removing /home/sgeorge/.cache/huggingface/metrics/squad/default/default_experiment-1-0.arrow
#   8%|▊         | 8/100 [00:00<00:01, 72.97it/s]2021-08-03 23:51:28,583 - Removing /home/sgeorge/.cache/huggingface/metrics/squad/default/default_experiment-1-0.arrow
# 2021-08-03 23:51:28,595 - Removing /home/sgeorge/.cache/huggingface/metrics/squad/default/default_experiment-1-0.arrow
# 2021-08-03 23:51:28,606 - Removing /home/sgeorge/.cache/huggingface/metrics/squad/default/default_experiment-1-0.arrow
# 2021-08-03 23:51:28,616 - Removing /home/sgeorge/.cache/huggingface/metrics/squad/default/default_experiment-1-0.arrow
# 2021-08-03 23:51:28,627 - Removing /home/sgeorge/.cache/huggingface/metrics/squad/default/default_experiment-1-0.arrow
# 2021-08-03 23:51:28,638 - Removing /home/sgeorge/.cache/huggingface/metrics/squad/default/default_experiment-1-0.arrow
# 2021-08-03 23:51:28,653 - Removing /home/sgeorge/.cache/huggingface/metrics/squad/default/default_experiment-1-0.arrow
# 2021-08-03 23:51:28,664 - Removing /home/sgeorge/.cache/huggingface/metrics/squad/default/default_experiment-1-0.arrow
# 2021-08-03 23:51:28,677 - Removing /home/sgeorge/.cache/huggingface/metrics/squad/default/default_experiment-1-0.arrow
#  17%|█▋        | 17/100 [00:00<00:01, 76.18it/s]2021-08-03 23:51:28,691 - Removing /home/sgeorge/.cache/huggingface/metrics/squad/default/default_experiment-1-0.arrow
# 2021-08-03 23:51:28,702 - Removing /home/sgeorge/.cache/huggingface/metrics/squad/default/default_experiment-1-0.arrow
# 2021-08-03 23:51:28,712 - Removing /home/sgeorge/.cache/huggingface/metrics/squad/default/default_experiment-1-0.arrow
# 2021-08-03 23:51:28,722 - Removing /home/sgeorge/.cache/huggingface/metrics/squad/default/default_experiment-1-0.arrow
# 2021-08-03 23:51:28,733 - Removing /home/sgeorge/.cache/huggingface/metrics/squad/default/default_experiment-1-0.arrow
# 2021-08-03 23:51:28,858 - Removing /home/sgeorge/.cache/huggingface/metrics/squad/default/default_experiment-1-0.arrow
#  23%|██▎       | 23/100 [00:00<00:01, 54.72it/s]2021-08-03 23:51:28,872 - Removing /home/sgeorge/.cache/huggingface/metrics/squad/default/default_experiment-1-0.arrow
# 2021-08-03 23:51:28,895 - Removing /home/sgeorge/.cache/huggingface/metrics/squad/default/default_experiment-1-0.arrow
# 2021-08-03 23:51:28,905 - Removing /home/sgeorge/.cache/huggingface/metrics/squad/default/default_experiment-1-0.arrow
# 2021-08-03 23:51:28,915 - Removing /home/sgeorge/.cache/huggingface/metrics/squad/default/default_experiment-1-0.arrow
# 2021-08-03 23:51:28,937 - Removing /home/sgeorge/.cache/huggingface/metrics/squad/default/default_experiment-1-0.arrow
# 2021-08-03 23:51:28,948 - Removing /home/sgeorge/.cache/huggingface/metrics/squad/default/default_experiment-1-0.arrow
# 2021-08-03 23:51:28,960 - Removing /home/sgeorge/.cache/huggingface/metrics/squad/default/default_experiment-1-0.arrow
#  30%|███       | 30/100 [00:00<00:01, 58.23it/s]2021-08-03 23:51:28,973 - Removing /home/sgeorge/.cache/huggingface/metrics/squad/default/default_experiment-1-0.arrow
# 2021-08-03 23:51:28,984 - Removing /home/sgeorge/.cache/huggingface/metrics/squad/default/default_experiment-1-0.arrow
# 2021-08-03 23:51:28,995 - Removing /home/sgeorge/.cache/huggingface/metrics/squad/default/default_experiment-1-0.arrow
# 2021-08-03 23:51:29,009 - Removing /home/sgeorge/.cache/huggingface/metrics/squad/default/default_experiment-1-0.arrow
# 2021-08-03 23:51:29,019 - Removing /home/sgeorge/.cache/huggingface/metrics/squad/default/default_experiment-1-0.arrow
# 2021-08-03 23:51:29,032 - Removing /home/sgeorge/.cache/huggingface/metrics/squad/default/default_experiment-1-0.arrow
# 2021-08-03 23:51:29,047 - Removing /home/sgeorge/.cache/huggingface/metrics/squad/default/default_experiment-1-0.arrow
# 2021-08-03 23:51:29,061 - Removing /home/sgeorge/.cache/huggingface/metrics/squad/default/default_experiment-1-0.arrow
#  38%|███▊      | 38/100 [00:00<00:00, 63.33it/s]2021-08-03 23:51:29,077 - Removing /home/sgeorge/.cache/huggingface/metrics/squad/default/default_experiment-1-0.arrow
# 2021-08-03 23:51:29,088 - Removing /home/sgeorge/.cache/huggingface/metrics/squad/default/default_experiment-1-0.arrow
# 2021-08-03 23:51:29,099 - Removing /home/sgeorge/.cache/huggingface/metrics/squad/default/default_experiment-1-0.arrow
# 2021-08-03 23:51:29,111 - Removing /home/sgeorge/.cache/huggingface/metrics/squad/default/default_experiment-1-0.arrow
# 2021-08-03 23:51:29,124 - Removing /home/sgeorge/.cache/huggingface/metrics/squad/default/default_experiment-1-0.arrow
# 2021-08-03 23:51:29,145 - Removing /home/sgeorge/.cache/huggingface/metrics/squad/default/default_experiment-1-0.arrow
#  44%|████▍     | 44/100 [00:00<00:01, 42.16it/s]2021-08-03 23:51:29,505 - Removing /home/sgeorge/.cache/huggingface/metrics/squad/default/default_experiment-1-0.arrow
# 2021-08-03 23:51:29,516 - Removing /home/sgeorge/.cache/huggingface/metrics/squad/default/default_experiment-1-0.arrow
# 2021-08-03 23:51:29,543 - Removing /home/sgeorge/.cache/huggingface/metrics/squad/default/default_experiment-1-0.arrow
# 2021-08-03 23:51:29,554 - Removing /home/sgeorge/.cache/huggingface/metrics/squad/default/default_experiment-1-0.arrow
# 2021-08-03 23:51:29,564 - Removing /home/sgeorge/.cache/huggingface/metrics/squad/default/default_experiment-1-0.arrow
#  49%|████▉     | 49/100 [00:01<00:01, 31.68it/s]2021-08-03 23:51:29,575 - Removing /home/sgeorge/.cache/huggingface/metrics/squad/default/default_experiment-1-0.arrow
# 2021-08-03 23:51:29,585 - Removing /home/sgeorge/.cache/huggingface/metrics/squad/default/default_experiment-1-0.arrow
# 2021-08-03 23:51:29,595 - Removing /home/sgeorge/.cache/huggingface/metrics/squad/default/default_experiment-1-0.arrow
# 2021-08-03 23:51:29,605 - Removing /home/sgeorge/.cache/huggingface/metrics/squad/default/default_experiment-1-0.arrow
# 2021-08-03 23:51:29,615 - Removing /home/sgeorge/.cache/huggingface/metrics/squad/default/default_experiment-1-0.arrow
# 2021-08-03 23:51:29,625 - Removing /home/sgeorge/.cache/huggingface/metrics/squad/default/default_experiment-1-0.arrow
# 2021-08-03 23:51:29,636 - Removing /home/sgeorge/.cache/huggingface/metrics/squad/default/default_experiment-1-0.arrow
# 2021-08-03 23:51:29,647 - Removing /home/sgeorge/.cache/huggingface/metrics/squad/default/default_experiment-1-0.arrow
# 2021-08-03 23:51:29,662 - Removing /home/sgeorge/.cache/huggingface/metrics/squad/default/default_experiment-1-0.arrow
# 2021-08-03 23:51:29,675 - Removing /home/sgeorge/.cache/huggingface/metrics/squad/default/default_experiment-1-0.arrow
#  59%|█████▉    | 59/100 [00:01<00:01, 39.35it/s]2021-08-03 23:51:29,686 - Removing /home/sgeorge/.cache/huggingface/metrics/squad/default/default_experiment-1-0.arrow
# 2021-08-03 23:51:29,696 - Removing /home/sgeorge/.cache/huggingface/metrics/squad/default/default_experiment-1-0.arrow
# 2021-08-03 23:51:29,706 - Removing /home/sgeorge/.cache/huggingface/metrics/squad/default/default_experiment-1-0.arrow
# 2021-08-03 23:51:29,717 - Removing /home/sgeorge/.cache/huggingface/metrics/squad/default/default_experiment-1-0.arrow
# 2021-08-03 23:51:29,727 - Removing /home/sgeorge/.cache/huggingface/metrics/squad/default/default_experiment-1-0.arrow
# 2021-08-03 23:51:29,737 - Removing /home/sgeorge/.cache/huggingface/metrics/squad/default/default_experiment-1-0.arrow
# 2021-08-03 23:51:29,747 - Removing /home/sgeorge/.cache/huggingface/metrics/squad/default/default_experiment-1-0.arrow
# 2021-08-03 23:51:29,757 - Removing /home/sgeorge/.cache/huggingface/metrics/squad/default/default_experiment-1-0.arrow
# 2021-08-03 23:51:29,767 - Removing /home/sgeorge/.cache/huggingface/metrics/squad/default/default_experiment-1-0.arrow
# 2021-08-03 23:51:29,779 - Removing /home/sgeorge/.cache/huggingface/metrics/squad/default/default_experiment-1-0.arrow
#  69%|██████▉   | 69/100 [00:01<00:00, 47.85it/s]2021-08-03 23:51:29,793 - Removing /home/sgeorge/.cache/huggingface/metrics/squad/default/default_experiment-1-0.arrow
# 2021-08-03 23:51:29,804 - Removing /home/sgeorge/.cache/huggingface/metrics/squad/default/default_experiment-1-0.arrow
# 2021-08-03 23:51:29,815 - Removing /home/sgeorge/.cache/huggingface/metrics/squad/default/default_experiment-1-0.arrow
# 2021-08-03 23:51:29,825 - Removing /home/sgeorge/.cache/huggingface/metrics/squad/default/default_experiment-1-0.arrow
# 2021-08-03 23:51:29,836 - Removing /home/sgeorge/.cache/huggingface/metrics/squad/default/default_experiment-1-0.arrow
# 2021-08-03 23:51:29,847 - Removing /home/sgeorge/.cache/huggingface/metrics/squad/default/default_experiment-1-0.arrow
# 2021-08-03 23:51:29,858 - Removing /home/sgeorge/.cache/huggingface/metrics/squad/default/default_experiment-1-0.arrow
# 2021-08-03 23:51:29,868 - Removing /home/sgeorge/.cache/huggingface/metrics/squad/default/default_experiment-1-0.arrow
# 2021-08-03 23:51:29,879 - Removing /home/sgeorge/.cache/huggingface/metrics/squad/default/default_experiment-1-0.arrow
#  78%|███████▊  | 78/100 [00:01<00:00, 55.60it/s]2021-08-03 23:51:29,891 - Removing /home/sgeorge/.cache/huggingface/metrics/squad/default/default_experiment-1-0.arrow
# 2021-08-03 23:51:29,901 - Removing /home/sgeorge/.cache/huggingface/metrics/squad/default/default_experiment-1-0.arrow
# 2021-08-03 23:51:29,912 - Removing /home/sgeorge/.cache/huggingface/metrics/squad/default/default_experiment-1-0.arrow
# 2021-08-03 23:51:29,922 - Removing /home/sgeorge/.cache/huggingface/metrics/squad/default/default_experiment-1-0.arrow
# 2021-08-03 23:51:29,933 - Removing /home/sgeorge/.cache/huggingface/metrics/squad/default/default_experiment-1-0.arrow
# 2021-08-03 23:51:29,944 - Removing /home/sgeorge/.cache/huggingface/metrics/squad/default/default_experiment-1-0.arrow
# 2021-08-03 23:51:29,954 - Removing /home/sgeorge/.cache/huggingface/metrics/squad/default/default_experiment-1-0.arrow
# 2021-08-03 23:51:29,965 - Removing /home/sgeorge/.cache/huggingface/metrics/squad/default/default_experiment-1-0.arrow
# 2021-08-03 23:51:29,975 - Removing /home/sgeorge/.cache/huggingface/metrics/squad/default/default_experiment-1-0.arrow
# 2021-08-03 23:51:29,985 - Removing /home/sgeorge/.cache/huggingface/metrics/squad/default/default_experiment-1-0.arrow
#  88%|████████▊ | 88/100 [00:01<00:00, 63.30it/s]2021-08-03 23:51:29,997 - Removing /home/sgeorge/.cache/huggingface/metrics/squad/default/default_experiment-1-0.arrow
# 2021-08-03 23:51:30,025 - Removing /home/sgeorge/.cache/huggingface/metrics/squad/default/default_experiment-1-0.arrow
# 2021-08-03 23:51:30,037 - Removing /home/sgeorge/.cache/huggingface/metrics/squad/default/default_experiment-1-0.arrow
# 2021-08-03 23:51:30,049 - Removing /home/sgeorge/.cache/huggingface/metrics/squad/default/default_experiment-1-0.arrow
# 2021-08-03 23:51:30,067 - Removing /home/sgeorge/.cache/huggingface/metrics/squad/default/default_experiment-1-0.arrow
# 2021-08-03 23:51:30,077 - Removing /home/sgeorge/.cache/huggingface/metrics/squad/default/default_experiment-1-0.arrow
# 2021-08-03 23:51:30,090 - Removing /home/sgeorge/.cache/huggingface/metrics/squad/default/default_experiment-1-0.arrow
# 2021-08-03 23:51:30,099 - Removing /home/sgeorge/.cache/huggingface/metrics/squad/default/default_experiment-1-0.arrow
#  96%|█████████▌| 96/100 [00:01<00:00, 65.39it/s]2021-08-03 23:51:30,110 - Removing /home/sgeorge/.cache/huggingface/metrics/squad/default/default_experiment-1-0.arrow
# 2021-08-03 23:51:30,122 - Removing /home/sgeorge/.cache/huggingface/metrics/squad/default/default_experiment-1-0.arrow
# 2021-08-03 23:51:30,136 - Removing /home/sgeorge/.cache/huggingface/metrics/squad/default/default_experiment-1-0.arrow
# 2021-08-03 23:51:30,147 - Removing /home/sgeorge/.cache/huggingface/metrics/squad/default/default_experiment-1-0.arrow
# 100%|██████████| 100/100 [00:01<00:00, 59.32it/s]
# CPU times: user 869 ms, sys: 78.5 ms, total: 947 ms
# Wall time: 1.69 s

# %%
metrics_df = pd.DataFrame(metric_list)
metrics_df.head()
# Out:
#    exact_match          f1                                        id
# 0          0.0   57.142857  21a3561031f2e909338196601f5c1ac2e08905b6
# 1          0.0   57.142857  21a3561031f2e909338196601f5c1ac2e08905b6
# 2          0.0   57.142857  21a3561031f2e909338196601f5c1ac2e08905b6
# 3          0.0   57.142857  21a3561031f2e909338196601f5c1ac2e08905b6
# 4        100.0  100.000000  21a3561031f2e909338196601f5c1ac2e08905b6

# %%
combined = combined.merge(metrics_df, on='id')

# %%
combined = combined[['id', 'checkpoint', 'seed', 'exact_match', 'f1']]
combined.head()
# Out:
#                                          id  checkpoint  seed  exact_match  \
# 0  21a3561031f2e909338196601f5c1ac2e08905b6           1    27          0.0
# 1  21a3561031f2e909338196601f5c1ac2e08905b6           1    27          0.0
# 2  21a3561031f2e909338196601f5c1ac2e08905b6           1    27          0.0
# 3  21a3561031f2e909338196601f5c1ac2e08905b6           1    27          0.0
# 4  21a3561031f2e909338196601f5c1ac2e08905b6           1    27        100.0
#
#            f1
# 0   57.142857
# 1   57.142857
# 2   57.142857
# 3   57.142857
# 4  100.000000

# %%
combined['dataset'] = 'dbert'
# Out:
# /home/sgeorge/.conda/envs/rclearn/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
combined.head()
# Out:
#                                          id  checkpoint  seed  exact_match  \
# 0  21a3561031f2e909338196601f5c1ac2e08905b6           1    27          0.0
# 1  21a3561031f2e909338196601f5c1ac2e08905b6           1    27          0.0
# 2  21a3561031f2e909338196601f5c1ac2e08905b6           1    27          0.0
# 3  21a3561031f2e909338196601f5c1ac2e08905b6           1    27          0.0
# 4  21a3561031f2e909338196601f5c1ac2e08905b6           1    27        100.0
#
#            f1 dataset
# 0   57.142857   dbert
# 1   57.142857   dbert
# 2   57.142857   dbert
# 3   57.142857   dbert
# 4  100.000000   dbert

# %%
combined.to_csv(ind)

# %%
metrics
# Out:
# {'exact_match': 0.0, 'f1': 0.0}

# %%
pd.DataFrame([metrics, {'exact_match': 4.0, 'f1': 95.0}])
# Out:
#    exact_match    f1
# 0          0.0   0.0
# 1          4.0  95.0

# %%
ex = combined.sample(n=1)
ex
# Out:
#                                               id          prediction_text  ...                                           question   title
# 105942  f3aa1b86ade4042fafbc444714911316c82238df  Warsaw area enlargement  ...  After the war, how did they first try to remed...  Warsaw
#
# [1 rows x 9 columns]

# %%
squad2_evaluation(
    ex[['id']], 
    ex[['prediction_text']],
    ex[['answers']]
)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-67-f5ff973c3a42> in <module>
#       2     ex[['id']],
#       3     ex[['prediction_text']],
# ----> 4     ex[['answers']]
#       5 )
#
# /SAN/intelsys/rclearn/when-do-reading-comprehension-models-learn/src/analysis/utils.py in squad2_evaluation(id_list, prediction_text_list, answers_list)
#      87     ]
#      88
# ---> 89     metrics = SQUAD_V2_METRIC.compute(predictions=predictions, references=references)
#      90
#      91     return metrics
#
# ~/.conda/envs/rclearn/lib/python3.7/site-packages/datasets/metric.py in compute(self, predictions, references, **kwargs)
#     388
#     389         if predictions is not None:
# --> 390             self.add_batch(predictions=predictions, references=references)
#     391         self._finalize()
#     392
#
# ~/.conda/envs/rclearn/lib/python3.7/site-packages/datasets/metric.py in add_batch(self, predictions, references)
#     429         """
#     430         batch = {"predictions": predictions, "references": references}
# --> 431         batch = self.info.features.encode_batch(batch)
#     432         if self.writer is None:
#     433             self._init_writer()
#
# ~/.conda/envs/rclearn/lib/python3.7/site-packages/datasets/features.py in encode_batch(self, batch)
#     959         for key, column in batch.items():
#     960             column = cast_to_python_objects(column)
# --> 961             encoded_batch[key] = [encode_nested_example(self[key], obj) for obj in column]
#     962         return encoded_batch
#     963
#
# ~/.conda/envs/rclearn/lib/python3.7/site-packages/datasets/features.py in <listcomp>(.0)
#     959         for key, column in batch.items():
#     960             column = cast_to_python_objects(column)
# --> 961             encoded_batch[key] = [encode_nested_example(self[key], obj) for obj in column]
#     962         return encoded_batch
#     963
#
# ~/.conda/envs/rclearn/lib/python3.7/site-packages/datasets/features.py in encode_nested_example(schema, obj)
#     846     if isinstance(schema, dict):
#     847         return {
# --> 848             k: encode_nested_example(sub_schema, sub_obj) for k, (sub_schema, sub_obj) in utils.zip_dict(schema, obj)
#     849         }
#     850     elif isinstance(schema, (list, tuple)):
#
# ~/.conda/envs/rclearn/lib/python3.7/site-packages/datasets/features.py in <dictcomp>(.0)
#     846     if isinstance(schema, dict):
#     847         return {
# --> 848             k: encode_nested_example(sub_schema, sub_obj) for k, (sub_schema, sub_obj) in utils.zip_dict(schema, obj)
#     849         }
#     850     elif isinstance(schema, (list, tuple)):
#
# ~/.conda/envs/rclearn/lib/python3.7/site-packages/datasets/features.py in encode_nested_example(schema, obj)
#     863             else:
#     864                 # obj is a single dict
# --> 865                 for k, (sub_schema, sub_objs) in utils.zip_dict(schema.feature, obj):
#     866                     list_dict[k] = [encode_nested_example(sub_schema, o) for o in sub_objs]
#     867                 return list_dict
#
# ~/.conda/envs/rclearn/lib/python3.7/site-packages/datasets/utils/py_utils.py in zip_dict(*dicts)
#      96     for key in set(itertools.chain(*dicts)):  # set merge all keys
#      97         # Will raise KeyError if the dict don't have the same keys
# ---> 98         yield key, tuple(d[key] for d in dicts)
#      99
#     100
#
# ~/.conda/envs/rclearn/lib/python3.7/site-packages/datasets/utils/py_utils.py in <genexpr>(.0)
#      96     for key in set(itertools.chain(*dicts)):  # set merge all keys
#      97         # Will raise KeyError if the dict don't have the same keys
# ---> 98         yield key, tuple(d[key] for d in dicts)
#      99
#     100
#
# KeyError: 'w'

# %%
squad1_evaluation(
    combined.iloc[0]['id'], 
    combined.iloc[0]['prediction_text'],
    combined.iloc[0]['answers']
)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-58-f6464dd6098a> in <module>
#       2     combined.iloc[0]['id'],
#       3     combined.iloc[0]['prediction_text'],
# ----> 4     combined.iloc[0]['answers']
#       5 )
#
# /SAN/intelsys/rclearn/when-do-reading-comprehension-models-learn/src/analysis/utils.py in squad1_evaluation(id_list, prediction_text_list, answers_list)
#     109     ]
#     110
# --> 111     metrics = SQUAD_V1_METRIC.compute(predictions=predictions, references=references)
#     112
#     113     return metrics
#
# ~/.conda/envs/rclearn/lib/python3.7/site-packages/datasets/metric.py in compute(self, predictions, references, **kwargs)
#     388
#     389         if predictions is not None:
# --> 390             self.add_batch(predictions=predictions, references=references)
#     391         self._finalize()
#     392
#
# ~/.conda/envs/rclearn/lib/python3.7/site-packages/datasets/metric.py in add_batch(self, predictions, references)
#     429         """
#     430         batch = {"predictions": predictions, "references": references}
# --> 431         batch = self.info.features.encode_batch(batch)
#     432         if self.writer is None:
#     433             self._init_writer()
#
# ~/.conda/envs/rclearn/lib/python3.7/site-packages/datasets/features.py in encode_batch(self, batch)
#     959         for key, column in batch.items():
#     960             column = cast_to_python_objects(column)
# --> 961             encoded_batch[key] = [encode_nested_example(self[key], obj) for obj in column]
#     962         return encoded_batch
#     963
#
# ~/.conda/envs/rclearn/lib/python3.7/site-packages/datasets/features.py in <listcomp>(.0)
#     959         for key, column in batch.items():
#     960             column = cast_to_python_objects(column)
# --> 961             encoded_batch[key] = [encode_nested_example(self[key], obj) for obj in column]
#     962         return encoded_batch
#     963
#
# ~/.conda/envs/rclearn/lib/python3.7/site-packages/datasets/features.py in encode_nested_example(schema, obj)
#     846     if isinstance(schema, dict):
#     847         return {
# --> 848             k: encode_nested_example(sub_schema, sub_obj) for k, (sub_schema, sub_obj) in utils.zip_dict(schema, obj)
#     849         }
#     850     elif isinstance(schema, (list, tuple)):
#
# ~/.conda/envs/rclearn/lib/python3.7/site-packages/datasets/features.py in <dictcomp>(.0)
#     846     if isinstance(schema, dict):
#     847         return {
# --> 848             k: encode_nested_example(sub_schema, sub_obj) for k, (sub_schema, sub_obj) in utils.zip_dict(schema, obj)
#     849         }
#     850     elif isinstance(schema, (list, tuple)):
#
# ~/.conda/envs/rclearn/lib/python3.7/site-packages/datasets/features.py in encode_nested_example(schema, obj)
#     863             else:
#     864                 # obj is a single dict
# --> 865                 for k, (sub_schema, sub_objs) in utils.zip_dict(schema.feature, obj):
#     866                     list_dict[k] = [encode_nested_example(sub_schema, o) for o in sub_objs]
#     867                 return list_dict
#
# ~/.conda/envs/rclearn/lib/python3.7/site-packages/datasets/utils/py_utils.py in zip_dict(*dicts)
#      96     for key in set(itertools.chain(*dicts)):  # set merge all keys
#      97         # Will raise KeyError if the dict don't have the same keys
# ---> 98         yield key, tuple(d[key] for d in dicts)
#      99
#     100
#
# ~/.conda/envs/rclearn/lib/python3.7/site-packages/datasets/utils/py_utils.py in <genexpr>(.0)
#      96     for key in set(itertools.chain(*dicts)):  # set merge all keys
#      97         # Will raise KeyError if the dict don't have the same keys
# ---> 98         yield key, tuple(d[key] for d in dicts)
#      99
#     100
#
# KeyError: 't'

# %%
combined.iloc[0][['prediction_text']].values
# Out:
# array([', twice the figure for the average profession'], dtype=object)
